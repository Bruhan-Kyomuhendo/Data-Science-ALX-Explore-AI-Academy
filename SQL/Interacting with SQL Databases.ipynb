# %% [markdown]
# Interacting with SQL packages

# %% [markdown]
# ## SQL Packages

# %% [markdown]
#  pymysql
# ipymsql

# %% [markdown]
# Magic commands

# %% [markdown]
#     % in line
#     %% multiple lines

# %%
#preparing the environment
# %load_ext sql

# %%
pip install sqlalchemy==1.4.4

# %% [markdown]
# # My SQL connection string
# '%sql mysql+pymsql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}'

# %%
# %sql mysql+pymysql://root:Bruhan123$@127.0.0.1:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     united_nations.access_to_basic_services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, 94.67, 98, 17.542806, 184.39, 2699700, 4.93),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, 94.67, 98, 17.794055, 137.28, 2699700, 4.96),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, 95.0, 98, 18.037776, 166.81, 2699700, 4.9),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, 95.0, 98, 18.276452, 179.34, 2699700, 4.85),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, 95.0, 98, 18.513673, 181.67, 2699700, 4.8)]

# %%
# %sql sqlite:///chinook.db
# Out:
# 'Connected: @chinook.db'

# %%
# %%sql
# SELECT
#     FirstName,
#     LastName,
#     HireDate
# From
#     Employees;
# Out:
#    mysql+pymysql://root:***@127.0.0.1:3306/united_nations
#    sqlite:///chinokdatabase
#    sqlite:///chinook
#  * sqlite:///chinook.db
# Done.
# [('Andrew', 'Adams', '2002-08-14 00:00:00'),
#  ('Nancy', 'Edwards', '2002-05-01 00:00:00'),
#  ('Jane', 'Peacock', '2002-04-01 00:00:00'),
#  ('Margaret', 'Park', '2003-05-03 00:00:00'),
#  ('Steve', 'Johnson', '2003-10-17 00:00:00'),
#  ('Michael', 'Mitchell', '2003-10-17 00:00:00'),
#  ('Robert', 'King', '2004-01-02 00:00:00'),
#  ('Laura', 'Callahan', '2004-03-04 00:00:00')]
