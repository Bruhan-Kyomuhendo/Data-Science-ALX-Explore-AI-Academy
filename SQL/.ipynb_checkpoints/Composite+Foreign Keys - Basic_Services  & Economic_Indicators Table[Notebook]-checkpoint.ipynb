# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Composite and foreign keys:  Basic_services and Economic_indicators tables
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we demonstrate how to divide a larger dataset into smaller tables and link them using relationships.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should:
# - Understand how to create composite keys that make up the primary key.
# - Understand how to create a foreign key that references a primary key in another table.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table created in MySQL Workbench, we are interested in creating tables that contain  the basic services and economic indicators data for each country and each year. We can apply the same queries in MySQL Workbench and in this notebook if we connect to our MySQL server. Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Bruhan123$@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line, and then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, 94.67, 98, 17.542806, 184.39, 2699700, 4.93),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, 94.67, 98, 17.794055, 137.28, 2699700, 4.96),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, 95.0, 98, 18.037776, 166.81, 2699700, 4.9),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, 95.0, 98, 18.276452, 179.34, 2699700, 4.85),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, 95.0, 98, 18.513673, 181.67, 2699700, 4.8)]

# %% [markdown]
# ## Exercise
#
# We want to do the following:
# 1. Create a table that contains data about access to basic services for each country and year.
# 2. Create a table that contains the economic indicators for each country and each year.

# %% [markdown]
# ### 1. Create a table that contains data about access to basic services for each country and year only.
#
# Create a table named `Basic_services` with the columns `Country_name`, `Time_period`, `Pct_managed_drinking_water_services`, and `Pct_managed_sanitation_services`, with `Country_name` and `Time_period` being the composite keys and `Country_name` being the foreign key.

# %%
# %%sql
#
# CREATE TABLE united_nations.Basic_Services (
#       Country_name VARCHAR(37),
#       Time_period INTEGER,
#       Pct_managed_drinking_water_services NUMERIC(5,2),
#       Pct_managed_sanitation_services NUMERIC(5,2),
#       PRIMARY KEY (Country_name, Time_period),
#       FOREIGN KEY (Country_name) REFERENCES Geographic_Location (Country_name));
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.OperationalError) (1050, "Table 'basic_services' already exists")
# [SQL: CREATE TABLE united_nations.Basic_Services (
#       Country_name VARCHAR(37),
#       Time_period INTEGER,
#       Pct_managed_drinking_water_services NUMERIC(5,2),
#       Pct_managed_sanitation_services NUMERIC(5,2),
#       PRIMARY KEY (Country_name, Time_period),
#       FOREIGN KEY (Country_name) REFERENCES Geographic_Location (Country_name));]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# Extract the columns `Country_name`, `Time_period`, `Pct_managed_drinking_water_services`, and `Pct_managed_sanitation_services` from the `Access_to_Basic_Services` table into the newly created `Basic_services` table.

# %%
# %%sql
#
# INSERT INTO Basic_Services (Country_name, Time_period, Pct_managed_drinking_water_services, Pct_managed_sanitation_services)
# SELECT Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services
# FROM united_nations.Access_to_Basic_Services;

# %% [markdown]
# ### 2. Create a table that contains the economic indicators.
#
# Create a table named `Economic_indicators` with the columns `Country_name`, `Time_period`, `Est_gdp_in_billions`, `Est_population_in_millions`, and `Pct_unemployment`, with `Country_name` and `Time_period` being the composite keys and `Country_name` being the foreign key.

# %%
# %%sql
#
# CREATE TABLE united_nations.Economic_Indicators (Country_name VARCHAR(37),
#     Time_period INTEGER,
#     Est_gdp_in_billions NUMERIC(8,2),
#     Est_population_in_millions NUMERIC(11,6),
#     Pct_unemployment NUMERIC(5,2),
#     PRIMARY KEY (Country_name, Time_period),
#     FOREIGN KEY (Country_name) REFERENCES Geographic_Location (Country_name)
# );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.OperationalError) (1050, "Table 'economic_indicators' already exists")
# [SQL: CREATE TABLE united_nations.Economic_Indicators (Country_name VARCHAR(37),
#     Time_period INTEGER,
#     Est_gdp_in_billions NUMERIC(8,2),
#     Est_population_in_millions NUMERIC(11,6),
#     Pct_unemployment NUMERIC(5,2),
#     PRIMARY KEY (Country_name, Time_period),
#     FOREIGN KEY (Country_name) REFERENCES Geographic_Location (Country_name)
# );]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# Extract the columns `Country_name`, `Time_period`, `Est_gdp_in_billions`, `Est_population_in_millions`, and `Pct_unemployment` from the `Access_to_Basic_Services` table into the newly created `Economic_indicators` table.

# %%
# %%sql
# INSERT INTO Economic_Indicators (Country_name, Time_period, Est_gdp_in_billions, Est_population_in_millions, Pct_unemployment)
# SELECT Country_name,
#     Time_period,
#     Est_gdp_in_billions,
#     Est_population_in_millions,
#     Pct_unemployment
# FROM united_nations.Access_to_Basic_Services;

# %%
# %%sql
#
# SELECT *
# FROM Economic_Indicators
# ORDER BY Pct_unemployment;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None),
#  ('Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None),
#  ('Afghanistan', 2018, Decimal('18.42'), Decimal('36.686784'), None),
#  ('Afghanistan', 2019, Decimal('18.90'), Decimal('37.769499'), None),
#  ('Algeria', 2018, Decimal('174.91'), Decimal('41.927007'), None),
#  ('Algeria', 2019, Decimal('171.77'), Decimal('42.705368'), None),
#  ('Algeria', 2020, Decimal('145.01'), Decimal('43.451666'), None),
#  ('American Samoa', 2015, Decimal('0.67'), Decimal('0.051368'), None),
#  ('American Samoa', 2016, Decimal('0.67'), Decimal('0.050448'), None),
#  ('American Samoa', 2017, Decimal('0.61'), Decimal('0.049463'), None),
#  ('American Samoa', 2018, Decimal('0.64'), Decimal('0.048424'), None),
#  ('American Samoa', 2019, Decimal('0.65'), Decimal('0.047321'), None),
#  ('American Samoa', 2020, Decimal('0.72'), Decimal('0.046189'), None),
#  ('Angola', 2015, Decimal('87.22'), Decimal('28.127721'), None),
#  ('Angola', 2016, Decimal('49.84'), Decimal('29.154746'), None),
#  ('Angola', 2017, Decimal('68.97'), Decimal('30.208628'), None),
#  ('Angola', 2018, Decimal('77.79'), Decimal('31.273533'), None),
#  ('Angola', 2020, Decimal('53.62'), Decimal('33.428486'), None),
#  ('Anguilla', 2015, None, None, None),
#  ('Anguilla', 2016, None, None, None),
#  ('Anguilla', 2017, None, None, None),
#  ('Antigua and Barbuda', 2015, Decimal('1.34'), Decimal('0.089941'), None),
#  ('Antigua and Barbuda', 2016, Decimal('1.44'), Decimal('0.090564'), None),
#  ('Antigua and Barbuda', 2017, Decimal('1.47'), Decimal('0.091119'), None),
#  ('Argentina', 2015, Decimal('594.75'), Decimal('43.131966'), None),
#  ('Argentina', 2016, Decimal('557.53'), Decimal('43.590368'), None),
#  ('Aruba', 2015, Decimal('2.96'), Decimal('0.104257'), None),
#  ('Aruba', 2016, Decimal('2.98'), Decimal('0.104874'), None),
#  ('Bahamas', 2015, None, None, None),
#  ('Bahamas', 2016, None, None, None),
#  ('Bahamas', 2017, None, None, None),
#  ('Bahamas', 2018, None, None, None),
#  ('Bahamas', 2019, None, None, None),
#  ('Bahrain', 2015, Decimal('31.05'), Decimal('1.362142'), None),
#  ('Bahrain', 2016, Decimal('32.23'), Decimal('1.409661'), None),
#  ('Bahrain', 2017, Decimal('35.47'), Decimal('1.456834'), None),
#  ('Bahrain', 2018, Decimal('37.80'), Decimal('1.487340'), None),
#  ('Bahrain', 2019, Decimal('38.65'), Decimal('1.494188'), None),
#  ('Bahrain', 2020, Decimal('34.72'), Decimal('1.477469'), None),
#  ('Bangladesh', 2015, Decimal('195.08'), Decimal('157.830000'), None),
#  ('Bangladesh', 2018, Decimal('321.38'), Decimal('163.683958'), None),
#  ('Bangladesh', 2019, Decimal('351.24'), Decimal('165.516222'), None),
#  ('Bangladesh', 2020, Decimal('373.90'), Decimal('167.420951'), None),
#  ('Barbados', 2020, Decimal('4.67'), Decimal('0.280693'), None),
#  ('Belize', 2018, Decimal('2.31'), Decimal('0.382066'), None),
#  ('Belize', 2020, Decimal('2.08'), Decimal('0.394921'), None),
#  ('Benin', 2015, Decimal('11.39'), Decimal('10.932783'), None),
#  ('Benin', 2016, Decimal('11.82'), Decimal('11.260085'), None),
#  ('Benin', 2017, Decimal('12.70'), Decimal('11.596779'), None),
#  ('Benin', 2019, Decimal('14.39'), Decimal('12.290444'), None),
#  ('Benin', 2020, Decimal('15.65'), Decimal('12.643123'), None),
#  ('Bermuda', 2015, Decimal('6.65'), Decimal('0.065237'), None),
#  ('Bermuda', 2016, Decimal('6.90'), Decimal('0.064554'), None),
#  ('Bermuda', 2017, Decimal('7.14'), Decimal('0.063873'), None),
#  ('Bermuda', 2018, Decimal('7.23'), Decimal('0.063918'), None),
#  ('Bermuda', 2019, Decimal('7.42'), Decimal('0.063911'), None),
#  ('Bermuda', 2020, Decimal('6.89'), Decimal('0.063893'), None),
#  ('Bhutan', 2016, Decimal('2.16'), Decimal('0.749761'), None),
#  ('Bhutan', 2017, Decimal('2.45'), Decimal('0.756121'), None),
#  ('Bolivia (Plurinational State of)', 2015, None, None, None),
#  ('Bolivia (Plurinational State of)', 2016, None, None, None),
#  ('Bolivia (Plurinational State of)', 2017, None, None, None),
#  ('Bolivia (Plurinational State of)', 2018, None, None, None),
#  ('Bolivia (Plurinational State of)', 2019, None, None, None),
#  ('Bolivia (Plurinational State of)', 2020, None, None, None),
#  ('Botswana', 2015, Decimal('13.53'), Decimal('2.305171'), None),
#  ('Botswana', 2016, Decimal('15.08'), Decimal('2.352416'), None),
#  ('Botswana', 2017, Decimal('16.11'), Decimal('2.401840'), None),
#  ('Botswana', 2018, Decimal('17.03'), Decimal('2.451409'), None),
#  ('British Virgin Islands', 2015, None, Decimal('0.029366'), None),
#  ('British Virgin Islands', 2016, None, Decimal('0.029739'), None),
#  ('British Virgin Islands', 2017, None, Decimal('0.030060'), None),
#  ('British Virgin Islands', 2018, None, Decimal('0.030335'), None),
#  ('British Virgin Islands', 2019, None, Decimal('0.030610'), None),
#  ('British Virgin Islands', 2020, None, Decimal('0.030910'), None),
#  ('Brunei Darussalam', 2015, Decimal('12.93'), Decimal('0.421437'), None),
#  ('Brunei Darussalam', 2016, Decimal('11.40'), Decimal('0.425994'), None),
#  ('Burkina Faso', 2015, Decimal('11.83'), Decimal('18.718019'), None),
#  ('Burkina Faso', 2016, Decimal('12.83'), Decimal('19.275498'), None),
#  ('Burkina Faso', 2017, Decimal('14.11'), Decimal('19.835858'), None),
#  ('Burkina Faso', 2019, Decimal('16.18'), Decimal('20.951639'), None),
#  ('Burkina Faso', 2020, Decimal('17.93'), Decimal('21.522626'), None),
#  ('Burundi', 2015, Decimal('3.10'), Decimal('10.727148'), None),
#  ('Burundi', 2016, Decimal('2.64'), Decimal('10.903327'), None),
#  ('Burundi', 2017, Decimal('2.71'), Decimal('11.155593'), None),
#  ('Burundi', 2018, Decimal('2.66'), Decimal('11.493472'), None),
#  ('Burundi', 2019, Decimal('2.58'), Decimal('11.874838'), None),
#  ("CÃ´te d'Ivoire", 2015, None, None, None),
#  ("CÃ´te d'Ivoire", 2016, None, None, None),
#  ("CÃ´te d'Ivoire", 2017, None, None, None),
#  ("CÃ´te d'Ivoire", 2018, None, None, None),
#  ("CÃ´te d'Ivoire", 2019, None, None, None),
#  ("CÃ´te d'Ivoire", 2020, None, None, None),
#  ('Cabo Verde', 2016, Decimal('1.66'), Decimal('0.558394'), None),
#  ('Cabo Verde', 2020, Decimal('1.70'), Decimal('0.582640'), None),
#  ('Cambodia', 2018, Decimal('24.57'), Decimal('16.025238'), None),
#  ('Cambodia', 2020, Decimal('25.87'), Decimal('16.396860'), None),
#  ('Cameroon', 2015, Decimal('32.21'), Decimal('23.012646'), None),
#  ('Cameroon', 2016, Decimal('33.81'), Decimal('23.711630'), None),
#  ('Cameroon', 2017, Decimal('36.10'), Decimal('24.393181'), None),
#  ('Cameroon', 2018, Decimal('39.97'), Decimal('25.076747'), None),
#  ('Cameroon', 2019, Decimal('39.67'), Decimal('25.782341'), None),
#  ('Cameroon', 2020, Decimal('40.77'), Decimal('26.491087'), None),
#  ('Cayman Islands', 2016, Decimal('4.91'), Decimal('0.062255'), None),
#  ('Central African Republic', 2015, Decimal('1.70'), Decimal('4.819333'), None),
#  ('Central African Republic', 2016, Decimal('1.83'), Decimal('4.904177'), None),
#  ('Central African Republic', 2017, Decimal('2.07'), Decimal('4.996741'), None),
#  ('Central African Republic', 2018, Decimal('2.22'), Decimal('5.094780'), None),
#  ('Central African Republic', 2019, Decimal('2.22'), Decimal('5.209324'), None),
#  ('Central African Republic', 2020, Decimal('2.33'), Decimal('5.343020'), None),
#  ('Chad', 2015, Decimal('10.95'), Decimal('14.140274'), None),
#  ('Chad', 2016, Decimal('10.10'), Decimal('14.592585'), None),
#  ('Chad', 2017, Decimal('10.00'), Decimal('15.085884'), None),
#  ('Chad', 2019, Decimal('11.31'), Decimal('16.126866'), None),
#  ('Chad', 2020, Decimal('10.72'), Decimal('16.644701'), None),
#  ('China', 2015, Decimal('11061.55'), Decimal('1379.860000'), None),
#  ('China', 2016, Decimal('11233.28'), Decimal('1387.790000'), None),
#  ('Comoros', 2015, Decimal('0.97'), Decimal('0.730216'), None),
#  ('Comoros', 2016, Decimal('1.01'), Decimal('0.746232'), None),
#  ('Comoros', 2017, Decimal('1.08'), Decimal('0.761664'), None),
#  ('Comoros', 2018, Decimal('1.19'), Decimal('0.776313'), None),
#  ('Comoros', 2019, Decimal('1.20'), Decimal('0.790986'), None),
#  ('Congo', 2015, None, None, None),
#  ('Congo', 2016, None, None, None),
#  ('Congo', 2017, None, None, None),
#  ('Congo', 2018, None, None, None),
#  ('Congo', 2019, None, None, None),
#  ('Congo', 2020, None, None, None),
#  ('Cook Islands', 2015, None, None, None),
#  ('Cook Islands', 2016, None, None, None),
#  ('Cook Islands', 2017, None, None, None),
#  ('Cook Islands', 2018, None, None, None),
#  ('Cook Islands', 2019, None, None, None),
#  ('Cook Islands', 2020, None, None, None),
#  ('Cuba', 2019, Decimal('103.43'), Decimal('11.316697'), None),
#  ('Cuba', 2020, Decimal('107.35'), Decimal('11.300698'), None),
#  ('CuraÃ§ao', 2015, None, None, None),
#  ('CuraÃ§ao', 2016, None, None, None),
#  ('CuraÃ§ao', 2017, None, None, None),
#  ("Democratic People's Republic of Korea", 2015, None, None, None),
#  ("Democratic People's Republic of Korea", 2016, None, None, None),
#  ("Democratic People's Republic of Korea", 2017, None, None, None),
#  ("Democratic People's Republic of Korea", 2018, None, None, None),
#  ("Democratic People's Republic of Korea", 2019, None, None, None),
#  ("Democratic People's Republic of Korea", 2020, None, None, None),
#  ('Democratic Republic of the Congo', 2015, None, None, None),
#  ('Democratic Republic of the Congo', 2016, None, None, None),
#  ('Democratic Republic of the Congo', 2017, None, None, None),
#  ('Democratic Republic of the Congo', 2018, None, None, None),
#  ('Democratic Republic of the Congo', 2019, None, None, None),
#  ('Democratic Republic of the Congo', 2020, None, None, None),
#  ('Djibouti', 2015, Decimal('2.42'), Decimal('1.006259'), None),
#  ('Djibouti', 2016, Decimal('2.60'), Decimal('1.023261'), None),
#  ('Djibouti', 2018, Decimal('2.91'), Decimal('1.057198'), None),
#  ('Djibouti', 2019, Decimal('3.09'), Decimal('1.073994'), None),
#  ('Djibouti', 2020, Decimal('3.18'), Decimal('1.090156'), None),
#  ('Dominica', 2015, Decimal('0.54'), Decimal('0.070007'), None),
#  ('Dominica', 2016, Decimal('0.58'), Decimal('0.070075'), None),
#  ('Dominica', 2017, Decimal('0.52'), Decimal('0.070403'), None),
#  ('Egypt', 2015, None, None, None),
#  ('Egypt', 2016, None, None, None),
#  ('Egypt', 2017, None, None, None),
#  ('Egypt', 2018, None, None, None),
#  ('Egypt', 2019, None, None, None),
#  ('Egypt', 2020, None, None, None),
#  ('Equatorial Guinea', 2015, Decimal('13.19'), Decimal('1.346973'), None),
#  ('Equatorial Guinea', 2016, Decimal('11.24'), Decimal('1.398927'), None),
#  ('Equatorial Guinea', 2017, Decimal('12.20'), Decimal('1.450694'), None),
#  ('Eritrea', 2015, None, Decimal('3.340006'), None),
#  ('Eritrea', 2016, None, Decimal('3.365287'), None),
#  ('Eswatini', 2015, Decimal('4.06'), Decimal('1.133936'), None),
#  ('Eswatini', 2017, Decimal('4.40'), Decimal('1.151390'), None),
#  ('Eswatini', 2018, Decimal('4.67'), Decimal('1.160428'), None),
#  ('Eswatini', 2019, Decimal('4.50'), Decimal('1.169613'), None),
#  ('Eswatini', 2020, Decimal('3.98'), Decimal('1.180655'), None),
#  ('Ethiopia', 2015, Decimal('64.59'), Decimal('102.471895'), None),
#  ('Ethiopia', 2016, Decimal('74.30'), Decimal('105.293228'), None),
#  ('Ethiopia', 2017, Decimal('81.77'), Decimal('108.197950'), None),
#  ('Ethiopia', 2018, Decimal('84.27'), Decimal('111.129438'), None),
#  ('Ethiopia', 2019, Decimal('95.91'), Decimal('114.120594'), None),
#  ('Ethiopia', 2020, Decimal('107.66'), Decimal('117.190911'), None),
#  ('Falkland Islands (Malvinas)', 2015, None, None, None),
#  ('Falkland Islands (Malvinas)', 2016, None, None, None),
#  ('Falkland Islands (Malvinas)', 2017, None, None, None),
#  ('Falkland Islands (Malvinas)', 2018, None, None, None),
#  ('Falkland Islands (Malvinas)', 2019, None, None, None),
#  ('Falkland Islands (Malvinas)', 2020, None, None, None),
#  ('Fiji', 2015, Decimal('4.68'), Decimal('0.917200'), None),
#  ('Fiji', 2017, Decimal('5.35'), Decimal('0.919019'), None),
#  ('Fiji', 2018, Decimal('5.58'), Decimal('0.918996'), None),
#  ('Fiji', 2019, Decimal('5.48'), Decimal('0.918465'), None),
#  ('Fiji', 2020, Decimal('4.48'), Decimal('0.920422'), None),
#  ('French Guiana', 2015, None, None, None),
#  ('French Guiana', 2016, None, None, None),
#  ('French Guiana', 2017, None, None, None),
#  ('French Guiana', 2018, None, None, None),
#  ('French Guiana', 2019, None, None, None),
#  ('French Guiana', 2020, None, None, None),
#  ('French Polynesia', 2015, Decimal('5.33'), Decimal('0.291787'), None),
#  ('French Polynesia', 2016, Decimal('5.50'), Decimal('0.293541'), None),
#  ('French Polynesia', 2017, Decimal('5.83'), Decimal('0.295450'), None),
#  ('French Polynesia', 2018, Decimal('6.14'), Decimal('0.297606'), None),
#  ('French Polynesia', 2019, Decimal('6.00'), Decimal('0.299717'), None),
#  ('French Polynesia', 2020, Decimal('5.71'), Decimal('0.301920'), None),
#  ('Gabon', 2015, Decimal('14.38'), Decimal('2.028517'), None),
#  ('Gabon', 2016, Decimal('14.02'), Decimal('2.086206'), None),
#  ('Gabon', 2017, Decimal('14.93'), Decimal('2.140215'), None),
#  ('Gabon', 2018, Decimal('16.87'), Decimal('2.192012'), None),
#  ('Gabon', 2019, Decimal('16.87'), Decimal('2.242785'), None),
#  ('Gabon', 2020, Decimal('15.31'), Decimal('2.292573'), None),
#  ('Gambia', 2015, None, None, None),
#  ('Gambia', 2016, None, None, None),
#  ('Gambia', 2017, None, None, None),
#  ('Gambia', 2018, None, None, None),
#  ('Gambia', 2019, None, None, None),
#  ('Gambia', 2020, None, None, None),
#  ('Ghana', 2016, Decimal('56.17'), Decimal('29.554303'), None),
#  ('Ghana', 2018, Decimal('67.30'), Decimal('30.870641'), None),
#  ('Ghana', 2019, Decimal('68.34'), Decimal('31.522290'), None),
#  ('Ghana', 2020, Decimal('70.04'), Decimal('32.180401'), None),
#  ('Greenland', 2016, Decimal('2.71'), Decimal('0.056186'), None),
#  ('Greenland', 2017, Decimal('2.85'), Decimal('0.056171'), None),
#  ('Greenland', 2018, Decimal('3.06'), Decimal('0.056023'), None),
#  ('Greenland', 2019, Decimal('2.99'), Decimal('0.056225'), None),
#  ('Greenland', 2020, Decimal('3.08'), Decimal('0.056367'), None),
#  ('Grenada', 2016, Decimal('1.06'), Decimal('0.119966'), None),
#  ('Grenada', 2017, Decimal('1.13'), Decimal('0.120921'), None),
#  ('Guadeloupe', 2015, None, None, None),
#  ('Guadeloupe', 2016, None, None, None),
#  ('Guadeloupe', 2017, None, None, None),
#  ('Guadeloupe', 2018, None, None, None),
#  ('Guadeloupe', 2019, None, None, None),
#  ('Guadeloupe', 2020, None, None, None),
#  ('Guam', 2017, Decimal('6.01'), Decimal('0.168606'), None),
#  ('Guam', 2018, Decimal('6.06'), Decimal('0.168678'), None),
#  ('Guam', 2019, Decimal('6.37'), Decimal('0.168624'), None),
#  ('Guam', 2020, Decimal('5.89'), Decimal('0.169231'), None),
#  ('Guatemala', 2020, Decimal('77.63'), Decimal('16.858333'), None),
#  ('Guinea', 2015, Decimal('8.79'), Decimal('11.625998'), None),
#  ('Guinea', 2016, Decimal('8.60'), Decimal('11.930985'), None),
#  ('Guinea', 2017, Decimal('10.32'), Decimal('12.240789'), None),
#  ('Guinea', 2018, Decimal('11.86'), Decimal('12.554864'), None),
#  ('Guinea', 2020, Decimal('14.18'), Decimal('13.205153'), None),
#  ('Guinea-Bissau', 2015, Decimal('1.05'), Decimal('1.788919'), None),
#  ('Guinea-Bissau', 2016, Decimal('1.18'), Decimal('1.834552'), None),
#  ('Guinea-Bissau', 2017, Decimal('1.35'), Decimal('1.879826'), None),
#  ('Guinea-Bissau', 2019, Decimal('1.44'), Decimal('1.970457'), None),
#  ('Guinea-Bissau', 2020, Decimal('1.43'), Decimal('2.015828'), None),
#  ('Guyana', 2015, Decimal('4.28'), Decimal('0.755031'), None),
#  ('Guyana', 2016, Decimal('4.48'), Decimal('0.759087'), None),
#  ('Guyana', 2017, Decimal('4.75'), Decimal('0.763252'), None),
#  ('Guyana', 2020, Decimal('5.47'), Decimal('0.797202'), None),
#  ('Haiti', 2015, Decimal('14.83'), Decimal('10.563757'), None),
#  ('Haiti', 2016, Decimal('13.99'), Decimal('10.713849'), None),
#  ('Haiti', 2017, Decimal('15.04'), Decimal('10.863543'), None),
#  ('Haiti', 2018, Decimal('16.46'), Decimal('11.012421'), None),
#  ('Haiti', 2019, Decimal('14.79'), Decimal('11.160438'), None),
#  ('Haiti', 2020, Decimal('14.51'), Decimal('11.306801'), None),
#  ('India', 2015, Decimal('2103.59'), Decimal('1322.866505'), None),
#  ('India', 2016, Decimal('2294.80'), Decimal('1338.636340'), None),
#  ('India', 2017, Decimal('2651.47'), Decimal('1354.195680'), None),
#  ('Iran (Islamic Republic of)', 2015, None, None, None),
#  ('Iran (Islamic Republic of)', 2016, None, None, None),
#  ('Iran (Islamic Republic of)', 2017, None, None, None),
#  ('Iran (Islamic Republic of)', 2018, None, None, None),
#  ('Iran (Islamic Republic of)', 2019, None, None, None),
#  ('Iran (Islamic Republic of)', 2020, None, None, None),
#  ('Iraq', 2015, Decimal('166.77'), Decimal('37.757813'), None),
#  ('Iraq', 2018, Decimal('227.37'), Decimal('40.590700'), None),
#  ('Iraq', 2019, Decimal('233.64'), Decimal('41.563520'), None),
#  ('Iraq', 2020, Decimal('184.37'), Decimal('42.556984'), None),
#  ('Kenya', 2015, Decimal('70.12'), Decimal('46.851488'), None),
#  ('Kenya', 2017, Decimal('82.04'), Decimal('48.948137'), None),
#  ('Kenya', 2018, Decimal('92.20'), Decimal('49.953304'), None),
#  ('Kenya', 2020, Decimal('100.67'), Decimal('51.985780'), None),
#  ('Kiribati', 2016, Decimal('0.18'), Decimal('0.118513'), None),
#  ('Kiribati', 2017, Decimal('0.19'), Decimal('0.120362'), None),
#  ('Kiribati', 2018, Decimal('0.20'), Decimal('0.122261'), None),
#  ('Kuwait', 2017, Decimal('120.71'), Decimal('4.124904'), None),
#  ('Kuwait', 2018, Decimal('138.18'), Decimal('4.317185'), None),
#  ('Kuwait', 2019, Decimal('136.20'), Decimal('4.441100'), None),
#  ('Kuwait', 2020, Decimal('105.96'), Decimal('4.360444'), None),
#  ('Kyrgyzstan', 2015, None, None, None),
#  ('Kyrgyzstan', 2016, None, None, None),
#  ('Kyrgyzstan', 2017, None, None, None),
#  ('Kyrgyzstan', 2018, None, None, None),
#  ('Kyrgyzstan', 2019, None, None, None),
#  ('Kyrgyzstan', 2020, None, None, None),
#  ("Lao People's Democratic Republic", 2015, None, None, None),
#  ("Lao People's Democratic Republic", 2016, None, None, None),
#  ("Lao People's Democratic Republic", 2017, None, None, None),
#  ("Lao People's Democratic Republic", 2018, None, None, None),
#  ("Lao People's Democratic Republic", 2019, None, None, None),
#  ("Lao People's Democratic Republic", 2020, None, None, None),
#  ('Lebanon', 2015, Decimal('49.93'), Decimal('6.398940'), None),
#  ('Lebanon', 2016, Decimal('51.15'), Decimal('6.258619'), None),
#  ('Lebanon', 2017, Decimal('53.03'), Decimal('6.109252'), None),
#  ('Lebanon', 2018, Decimal('54.90'), Decimal('5.950839'), None),
#  ('Lebanon', 2020, Decimal('31.71'), Decimal('5.662923'), None),
#  ('Lesotho', 2015, Decimal('2.36'), Decimal('2.118521'), None),
#  ('Lesotho', 2016, Decimal('2.11'), Decimal('2.143872'), None),
#  ('Lesotho', 2017, Decimal('2.31'), Decimal('2.170617'), None),
#  ('Lesotho', 2018, Decimal('2.55'), Decimal('2.198017'), None),
#  ('Lesotho', 2020, Decimal('2.23'), Decimal('2.254100'), None),
#  ('Liberia', 2015, Decimal('3.23'), Decimal('4.612329'), None),
#  ('Liberia', 2018, Decimal('3.42'), Decimal('4.889391'), None),
#  ('Liberia', 2019, Decimal('3.32'), Decimal('4.985289'), None),
#  ('Liberia', 2020, Decimal('3.04'), Decimal('5.087584'), None),
#  ('Libya', 2015, Decimal('48.72'), Decimal('6.192235'), None),
#  ('Libya', 2016, Decimal('49.91'), Decimal('6.282196'), None),
#  ('Libya', 2017, Decimal('67.16'), Decimal('6.378261'), None),
#  ('Libya', 2018, Decimal('76.68'), Decimal('6.477793'), None),
#  ('Libya', 2019, Decimal('69.25'), Decimal('6.569088'), None),
#  ('Libya', 2020, Decimal('50.36'), Decimal('6.653942'), None),
#  ('Madagascar', 2016, Decimal('11.85'), Decimal('25.501941'), None),
#  ('Madagascar', 2017, Decimal('13.18'), Decimal('26.169542'), None),
#  ('Madagascar', 2018, Decimal('13.76'), Decimal('26.846541'), None),
#  ('Madagascar', 2019, Decimal('14.10'), Decimal('27.533134'), None),
#  ('Madagascar', 2020, Decimal('13.05'), Decimal('28.225177'), None),
#  ('Malawi', 2015, Decimal('6.37'), Decimal('16.938942'), None),
#  ('Malawi', 2016, Decimal('5.43'), Decimal('17.405624'), None),
#  ('Malawi', 2018, Decimal('9.88'), Decimal('18.367883'), None),
#  ('Malawi', 2019, Decimal('11.03'), Decimal('18.867337'), None),
#  ('Maldives', 2015, Decimal('4.11'), Decimal('0.435582'), None),
#  ('Maldives', 2017, Decimal('4.75'), Decimal('0.472442'), None),
#  ('Maldives', 2018, Decimal('5.30'), Decimal('0.489758'), None),
#  ('Maldives', 2020, Decimal('3.75'), Decimal('0.514438'), None),
#  ('Mali', 2019, Decimal('17.28'), Decimal('20.567424'), None),
#  ('Marshall Islands', 2015, Decimal('0.18'), Decimal('0.049410'), None),
#  ('Marshall Islands', 2016, Decimal('0.20'), Decimal('0.048329'), None),
#  ('Marshall Islands', 2017, Decimal('0.21'), Decimal('0.047187'), None),
#  ('Marshall Islands', 2018, Decimal('0.22'), Decimal('0.045989'), None),
#  ('Marshall Islands', 2020, Decimal('0.24'), Decimal('0.043413'), None),
#  ('Martinique', 2015, None, None, None),
#  ('Martinique', 2016, None, None, None),
#  ('Martinique', 2017, None, None, None),
#  ('Martinique', 2018, None, None, None),
#  ('Martinique', 2019, None, None, None),
#  ('Martinique', 2020, None, None, None),
#  ('Mauritania', 2015, Decimal('6.17'), Decimal('3.946220'), None),
#  ('Mauritania', 2016, Decimal('6.40'), Decimal('4.051890'), None),
#  ('Mauritania', 2018, Decimal('7.47'), Decimal('4.270712'), None),
#  ('Mauritania', 2020, Decimal('8.41'), Decimal('4.498604'), None),
#  ('Mayotte', 2015, None, None, None),
#  ('Mayotte', 2016, None, None, None),
#  ('Mayotte', 2017, None, None, None),
#  ('Mayotte', 2018, None, None, None),
#  ('Mayotte', 2019, None, None, None),
#  ('Mayotte', 2020, None, None, None),
#  ('Micronesia (Federated States of)', 2015, None, None, None),
#  ('Micronesia (Federated States of)', 2016, None, None, None),
#  ('Micronesia (Federated States of)', 2017, None, None, None),
#  ('Micronesia (Federated States of)', 2018, None, None, None),
#  ('Micronesia (Federated States of)', 2019, None, None, None),
#  ('Montserrat', 2015, None, None, None),
#  ('Montserrat', 2016, None, None, None),
#  ('Montserrat', 2017, None, None, None),
#  ('Montserrat', 2018, None, None, None),
#  ('Montserrat', 2019, None, None, None),
#  ('Montserrat', 2020, None, None, None),
#  ('Morocco', 2017, Decimal('118.54'), Decimal('35.528115'), None),
#  ('Morocco', 2018, Decimal('127.34'), Decimal('35.927511'), None),
#  ('Morocco', 2019, Decimal('128.92'), Decimal('36.304408'), None),
#  ('Morocco', 2020, Decimal('121.35'), Decimal('36.688772'), None),
#  ('Mozambique', 2016, Decimal('11.94'), Decimal('27.696493'), None),
#  ('Mozambique', 2017, Decimal('13.22'), Decimal('28.569441'), None),
#  ('Mozambique', 2018, Decimal('14.85'), Decimal('29.423878'), None),
#  ('Mozambique', 2019, Decimal('15.39'), Decimal('30.285595'), None),
#  ('Mozambique', 2020, Decimal('14.03'), Decimal('31.178239'), None),
#  ('Myanmar', 2016, Decimal('60.29'), Decimal('51.892349'), None),
#  ('Namibia', 2015, Decimal('11.34'), Decimal('2.282704'), None),
#  ('Namibia', 2017, Decimal('12.90'), Decimal('2.364534'), None),
#  ('Namibia', 2019, Decimal('12.54'), Decimal('2.446644'), None),
#  ('Namibia', 2020, Decimal('10.58'), Decimal('2.489098'), None),
#  ('Nauru', 2015, Decimal('0.09'), Decimal('0.011185'), None),
#  ('Nauru', 2016, Decimal('0.10'), Decimal('0.011437'), None),
#  ('Nauru', 2017, Decimal('0.11'), Decimal('0.011682'), None),
#  ('Nauru', 2018, Decimal('0.12'), Decimal('0.011924'), None),
#  ('Nauru', 2019, Decimal('0.12'), Decimal('0.012132'), None),
#  ('Nauru', 2020, Decimal('0.11'), Decimal('0.012315'), None),
#  ('Nepal', 2016, Decimal('24.52'), Decimal('27.861186'), None),
#  ('Nepal', 2018, Decimal('33.11'), Decimal('28.506712'), None),
#  ('Nepal', 2019, Decimal('34.19'), Decimal('28.832496'), None),
#  ('Nepal', 2020, Decimal('33.43'), Decimal('29.348627'), None),
#  ('New Caledonia', 2015, Decimal('8.74'), Decimal('0.269460'), None),
#  ('New Caledonia', 2016, Decimal('8.72'), Decimal('0.270220'), None),
#  ('Nicaragua', 2019, Decimal('12.60'), Decimal('6.663924'), None),
#  ('Nicaragua', 2020, Decimal('12.59'), Decimal('6.755895'), None),
#  ('Niger', 2015, Decimal('9.68'), Decimal('20.128124'), None),
#  ('Niger', 2016, Decimal('10.40'), Decimal('20.921743'), None),
#  ('Niger', 2018, Decimal('12.81'), Decimal('22.577058'), None),
#  ('Niger', 2019, Decimal('12.92'), Decimal('23.443393'), None),
#  ('Niger', 2020, Decimal('13.74'), Decimal('24.333639'), None),
#  ('Nigeria', 2018, Decimal('421.74'), Decimal('198.387623'), None),
#  ('Nigeria', 2020, Decimal('432.20'), Decimal('208.327405'), None),
#  ('Niue', 2015, None, None, None),
#  ('Niue', 2016, None, None, None),
#  ('Niue', 2017, None, None, None),
#  ('Niue', 2018, None, None, None),
#  ('Niue', 2019, None, None, None),
#  ('Niue', 2020, None, None, None),
#  ('Northern Mariana Islands', 2015, Decimal('0.91'), Decimal('0.051514'), None),
#  ('Northern Mariana Islands', 2016, Decimal('1.23'), Decimal('0.051133'), None),
#  ('Northern Mariana Islands', 2017, Decimal('1.56'), Decimal('0.050729'), None),
#  ('Northern Mariana Islands', 2018, Decimal('1.30'), Decimal('0.050304'), None),
#  ('Northern Mariana Islands', 2019, Decimal('1.18'), Decimal('0.049858'), None),
#  ('Northern Mariana Islands', 2020, None, Decimal('0.049587'), None),
#  ('Oman', 2015, Decimal('78.71'), Decimal('4.191776'), None),
#  ('Oman', 2017, Decimal('80.86'), Decimal('4.541854'), None),
#  ('Oman', 2019, Decimal('88.06'), Decimal('4.602768'), None),
#  ('Pakistan', 2016, Decimal('313.63'), Decimal('213.524840'), None),
#  ('Pakistan', 2017, Decimal('339.21'), Decimal('216.379655'), None),
#  ('Pakistan', 2020, Decimal('300.43'), Decimal('227.196741'), None),
#  ('Palau', 2015, Decimal('0.28'), Decimal('0.017794'), None),
#  ('Palau', 2016, Decimal('0.30'), Decimal('0.017816'), None),
#  ('Palau', 2017, Decimal('0.29'), Decimal('0.017837'), None),
#  ('Palau', 2018, Decimal('0.28'), Decimal('0.017864'), None),
#  ('Palau', 2019, Decimal('0.28'), Decimal('0.017916'), None),
#  ('Papua New Guinea', 2015, Decimal('21.72'), Decimal('8.682174'), None),
#  ('Papua New Guinea', 2016, Decimal('20.76'), Decimal('8.899169'), None),
#  ('Papua New Guinea', 2017, Decimal('22.74'), Decimal('9.114796'), None),
#  ('Papua New Guinea', 2018, Decimal('24.11'), Decimal('9.329227'), None),
#  ('Papua New Guinea', 2019, Decimal('24.75'), Decimal('9.542486'), None),
#  ('Papua New Guinea', 2020, Decimal('23.85'), Decimal('9.749640'), None),
#  ('Puerto Rico', 2020, Decimal('103.02'), Decimal('3.281538'), None),
#  ('RÃ©union', 2015, None, None, None),
#  ('RÃ©union', 2016, None, None, None),
#  ('RÃ©union', 2017, None, None, None),
#  ('RÃ©union', 2018, None, None, None),
#  ('RÃ©union', 2019, None, None, None),
#  ('RÃ©union', 2020, None, None, None),
#  ('Republic of Korea', 2015, None, None, None),
#  ('Republic of Korea', 2016, None, None, None),
#  ('Republic of Korea', 2017, None, None, None),
#  ('Republic of Korea', 2018, None, None, None),
#  ('Republic of Korea', 2019, None, None, None),
#  ('Republic of Korea', 2020, None, None, None),
#  ('Rwanda', 2015, Decimal('8.54'), Decimal('11.642959'), None),
#  ('Rwanda', 2016, Decimal('8.69'), Decimal('11.930899'), None),
#  ('Saint BarthÃ©lemy', 2015, None, None, None),
#  ('Saint BarthÃ©lemy', 2016, None, None, None),
#  ('Saint BarthÃ©lemy', 2017, None, None, None),
#  ('Saint BarthÃ©lemy', 2018, None, None, None),
#  ('Saint BarthÃ©lemy', 2019, None, None, None),
#  ('Saint BarthÃ©lemy', 2020, None, None, None),
#  ('Saint Helena', 2015, None, None, None),
#  ('Saint Helena', 2016, None, None, None),
#  ('Saint Helena', 2017, None, None, None),
#  ('Saint Helena', 2018, None, None, None),
#  ('Saint Helena', 2019, None, None, None),
#  ('Saint Helena', 2020, None, None, None),
#  ('Saint Kitts and Nevis', 2015, None, None, None),
#  ('Saint Kitts and Nevis', 2016, None, None, None),
#  ('Saint Kitts and Nevis', 2017, None, None, None),
#  ('Saint Lucia', 2015, None, None, None),
#  ('Saint Lucia', 2016, None, None, None),
#  ('Saint Lucia', 2017, None, None, None),
#  ('Saint Lucia', 2018, None, None, None),
#  ('Saint Lucia', 2019, None, None, None),
#  ('Saint Lucia', 2020, None, None, None),
#  ('Saint Martin (French Part)', 2015, None, None, None),
#  ('Saint Martin (French Part)', 2016, None, None, None),
#  ('Saint Martin (French Part)', 2017, None, None, None),
#  ('Saint Martin (French Part)', 2018, None, None, None),
#  ('Saint Martin (French Part)', 2019, None, None, None),
#  ('Saint Martin (French Part)', 2020, None, None, None),
#  ('Saint Pierre and Miquelon', 2015, None, None, None),
#  ('Saint Pierre and Miquelon', 2016, None, None, None),
#  ('Saint Pierre and Miquelon', 2017, None, None, None),
#  ('Saint Pierre and Miquelon', 2018, None, None, None),
#  ('Saint Pierre and Miquelon', 2019, None, None, None),
#  ('Saint Pierre and Miquelon', 2020, None, None, None),
#  ('Saint Vincent and the Grenadines', 2015, None, None, None),
#  ('Saint Vincent and the Grenadines', 2016, None, None, None),
#  ('Saint Vincent and the Grenadines', 2017, None, None, None),
#  ('Saint Vincent and the Grenadines', 2018, None, None, None),
#  ('Samoa', 2015, Decimal('0.82'), Decimal('0.203571'), None),
#  ('Samoa', 2016, Decimal('0.84'), Decimal('0.205544'), None),
#  ('Samoa', 2018, Decimal('0.88'), Decimal('0.209701'), None),
#  ('Samoa', 2019, Decimal('0.91'), Decimal('0.211905'), None),
#  ('Samoa', 2020, Decimal('0.87'), Decimal('0.214929'), None),
#  ('Sao Tome and Principe', 2015, Decimal('0.32'), Decimal('0.201124'), None),
#  ('Sao Tome and Principe', 2016, Decimal('0.35'), Decimal('0.204632'), None),
#  ('Sao Tome and Principe', 2017, Decimal('0.38'), Decimal('0.208036'), None),
#  ('Sao Tome and Principe', 2018, Decimal('0.41'), Decimal('0.211344'), None),
#  ('Sao Tome and Principe', 2019, Decimal('0.43'), Decimal('0.214599'), None),
#  ('Sao Tome and Principe', 2020, Decimal('0.47'), Decimal('0.218641'), None),
#  ('Senegal', 2020, Decimal('24.49'), Decimal('16.436120'), None),
#  ('Sierra Leone', 2015, Decimal('4.22'), Decimal('7.314773'), None),
#  ('Sierra Leone', 2016, Decimal('3.67'), Decimal('7.493913'), None),
#  ('Sierra Leone', 2017, Decimal('3.72'), Decimal('7.677565'), None),
#  ('Sierra Leone', 2019, Decimal('4.08'), Decimal('8.046828'), None),
#  ('Sierra Leone', 2020, Decimal('4.06'), Decimal('8.233970'), None),
#  ('Singapore', 2018, Decimal('377.00'), Decimal('5.638676'), None),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('1.25'), Decimal('0.038825'), None),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('1.26'), Decimal('0.039969'), None),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('1.19'), Decimal('0.040574'), None),
#  ('Solomon Islands', 2015, Decimal('1.31'), Decimal('0.612660'), None),
#  ('Solomon Islands', 2016, Decimal('1.38'), Decimal('0.628102'), None),
#  ('Solomon Islands', 2017, Decimal('1.47'), Decimal('0.643634'), None),
#  ('Solomon Islands', 2018, Decimal('1.62'), Decimal('0.659249'), None),
#  ('Solomon Islands', 2019, Decimal('1.62'), Decimal('0.674993'), None),
#  ('Solomon Islands', 2020, Decimal('1.54'), Decimal('0.691191'), None),
#  ('Somalia', 2015, Decimal('5.33'), Decimal('13.763906'), None),
#  ('Somalia', 2016, Decimal('5.53'), Decimal('14.292847'), None),
#  ('Somalia', 2017, Decimal('5.61'), Decimal('14.864221'), None),
#  ('Somalia', 2018, Decimal('5.86'), Decimal('15.411094'), None),
#  ('Somalia', 2020, Decimal('6.88'), Decimal('16.537016'), None),
#  ('South Sudan', 2015, Decimal('12.00'), Decimal('11.194299'), None),
#  ('South Sudan', 2016, None, Decimal('11.066105'), None),
#  ('South Sudan', 2017, None, Decimal('10.658226'), None),
#  ('South Sudan', 2018, None, Decimal('10.395329'), None),
#  ('South Sudan', 2019, None, Decimal('10.447666'), None),
#  ('South Sudan', 2020, None, Decimal('10.606227'), None),
#  ('State of Palestine', 2015, None, None, None),
#  ('State of Palestine', 2016, None, None, None),
#  ('State of Palestine', 2017, None, None, None),
#  ('State of Palestine', 2018, None, None, None),
#  ('State of Palestine', 2019, None, None, None),
#  ('State of Palestine', 2020, None, None, None),
#  ('Sudan', 2015, Decimal('84.99'), Decimal('38.171178'), None),
#  ('Sudan', 2016, Decimal('102.94'), Decimal('39.377169'), None),
#  ('Sudan', 2017, Decimal('129.72'), Decimal('40.679828'), None),
#  ('Sudan', 2018, Decimal('32.33'), Decimal('41.999059'), None),
#  ('Sudan', 2019, Decimal('32.34'), Decimal('43.232093'), None),
#  ('Sudan', 2020, Decimal('27.03'), Decimal('44.440486'), None),
#  ('Suriname', 2017, Decimal('3.59'), Decimal('0.587559'), None),
#  ('Suriname', 2018, Decimal('4.00'), Decimal('0.593715'), None),
#  ('Suriname', 2019, Decimal('4.02'), Decimal('0.600301'), None),
#  ('Suriname', 2020, Decimal('2.91'), Decimal('0.607065'), None),
#  ('Syrian Arab Republic', 2015, Decimal('16.47'), Decimal('19.205178'), None),
#  ('Syrian Arab Republic', 2016, Decimal('12.60'), Decimal('18.964252'), None),
#  ('Syrian Arab Republic', 2017, Decimal('16.37'), Decimal('18.983373'), None),
#  ('Syrian Arab Republic', 2018, Decimal('21.35'), Decimal('19.333463'), None),
#  ('Syrian Arab Republic', 2019, Decimal('22.44'), Decimal('20.098251'), None),
#  ('Syrian Arab Republic', 2020, Decimal('11.08'), Decimal('20.772595'), None),
#  ('TÃ¼rkiye', 2015, None, None, None),
#  ('TÃ¼rkiye', 2016, None, None, None),
#  ('TÃ¼rkiye', 2017, None, None, None),
#  ('TÃ¼rkiye', 2018, None, None, None),
#  ('TÃ¼rkiye', 2019, None, None, None),
#  ('TÃ¼rkiye', 2020, None, None, None),
#  ('Tajikistan', 2015, Decimal('8.27'), Decimal('8.524063'), None),
#  ('Tajikistan', 2017, Decimal('7.54'), Decimal('8.925525'), None),
#  ('Tajikistan', 2018, Decimal('7.77'), Decimal('9.128132'), None),
#  ('Tajikistan', 2019, Decimal('8.30'), Decimal('9.337003'), None),
#  ('Tajikistan', 2020, Decimal('8.13'), Decimal('9.543207'), None),
#  ('Timor-Leste', 2015, Decimal('1.59'), Decimal('1.205813'), None),
#  ('Timor-Leste', 2017, Decimal('1.60'), Decimal('1.243235'), None),
#  ('Timor-Leste', 2018, Decimal('1.56'), Decimal('1.261845'), None),
#  ('Timor-Leste', 2019, Decimal('2.03'), Decimal('1.280438'), None),
#  ('Timor-Leste', 2020, Decimal('2.16'), Decimal('1.299995'), None),
#  ('Togo', 2016, Decimal('6.03'), Decimal('7.661354'), None),
#  ('Togo', 2018, Decimal('7.11'), Decimal('8.046679'), None),
#  ('Togo', 2019, Decimal('7.22'), Decimal('8.243094'), None),
#  ('Togo', 2020, Decimal('7.57'), Decimal('8.442580'), None),
#  ('Tokelau', 2015, None, None, None),
#  ('Tokelau', 2016, None, None, None),
#  ('Tokelau', 2017, None, None, None),
#  ('Tokelau', 2018, None, None, None),
#  ('Tokelau', 2019, None, None, None),
#  ('Tokelau', 2020, None, None, None),
#  ('Tonga', 2015, Decimal('0.44'), Decimal('0.106122'), None),
#  ('Tonga', 2016, Decimal('0.42'), Decimal('0.105707'), None),
#  ('Tonga', 2017, Decimal('0.46'), Decimal('0.105415'), None),
#  ('Tonga', 2019, Decimal('0.51'), Decimal('0.104951'), None),
#  ('Tonga', 2020, Decimal('0.48'), Decimal('0.105254'), None),
#  ('Trinidad and Tobago', 2017, Decimal('23.80'), Decimal('1.478607'), None),
#  ('Trinidad and Tobago', 2018, Decimal('24.32'), Decimal('1.504709'), None),
#  ('Tunisia', 2020, Decimal('42.54'), Decimal('12.161723'), None),
#  ('Turkmenistan', 2015, Decimal('35.80'), Decimal('5.766431'), None),
#  ('Turkmenistan', 2016, Decimal('36.17'), Decimal('5.868561'), None),
#  ('Turkmenistan', 2017, Decimal('37.93'), Decimal('5.968383'), None),
#  ('Turkmenistan', 2018, Decimal('40.77'), Decimal('6.065066'), None),
#  ('Turkmenistan', 2019, Decimal('45.23'), Decimal('6.158420'), None),
#  ('Turkmenistan', 2020, None, Decimal('6.250438'), None),
#  ('Turks and Caicos Islands', 2015, Decimal('0.94'), Decimal('0.036538'), None),
#  ('Turks and Caicos Islands', 2016, Decimal('1.03'), Decimal('0.038246'), None),
#  ('Turks and Caicos Islands', 2017, Decimal('1.02'), Decimal('0.039844'), None),
#  ('Turks and Caicos Islands', 2018, Decimal('1.11'), Decimal('0.041487'), None),
#  ('Tuvalu', 2015, Decimal('0.04'), Decimal('0.010877'), None),
#  ('Tuvalu', 2018, Decimal('0.05'), Decimal('0.010865'), None),
#  ('Tuvalu', 2019, Decimal('0.05'), Decimal('0.010956'), None),
#  ('Tuvalu', 2020, Decimal('0.06'), Decimal('0.011069'), None),
#  ('Uganda', 2015, Decimal('32.39'), Decimal('37.477356'), None),
#  ('Uganda', 2016, Decimal('29.20'), Decimal('38.748299'), None),
#  ('Uganda', 2018, Decimal('32.93'), Decimal('41.515395'), None),
#  ('Uganda', 2019, Decimal('35.35'), Decimal('42.949080'), None),
#  ('Uganda', 2020, Decimal('37.60'), Decimal('44.404611'), None),
#  ('United Arab Emirates', 2015, Decimal('370.28'), Decimal('8.916899'), None),
#  ('United Republic of Tanzania', 2015, None, None, None),
#  ('United Republic of Tanzania', 2016, None, None, None),
#  ('United Republic of Tanzania', 2017, None, None, None),
#  ('United Republic of Tanzania', 2018, None, None, None),
#  ('United Republic of Tanzania', 2019, None, None, None),
#  ('United Republic of Tanzania', 2020, None, None, None),
#  ('United States of America', 2015, None, None, None),
#  ('United States of America', 2016, None, None, None),
#  ('United States of America', 2017, None, None, None),
#  ('United States of America', 2018, None, None, None),
#  ('United States of America', 2019, None, None, None),
#  ('United States of America', 2020, None, None, None),
#  ('United States Virgin Islands', 2015, None, None, None),
#  ('United States Virgin Islands', 2016, None, None, None),
#  ('United States Virgin Islands', 2017, None, None, None),
#  ('United States Virgin Islands', 2018, None, None, None),
#  ('United States Virgin Islands', 2019, None, None, None),
#  ('United States Virgin Islands', 2020, None, None, None),
#  ('Vanuatu', 2015, Decimal('0.73'), Decimal('0.276438'), None),
#  ('Vanuatu', 2016, Decimal('0.78'), Decimal('0.283218'), None),
#  ('Vanuatu', 2017, Decimal('0.88'), Decimal('0.290239'), None),
#  ('Vanuatu', 2018, Decimal('0.91'), Decimal('0.297298'), None),
#  ('Venezuela (Bolivarian Republic of)', 2015, None, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2016, None, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2017, None, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2018, None, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2019, None, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2020, None, None, None),
#  ('Viet Nam', 2015, None, None, None),
#  ('Viet Nam', 2016, None, None, None),
#  ('Viet Nam', 2017, None, None, None),
#  ('Viet Nam', 2018, None, None, None),
#  ('Viet Nam', 2019, None, None, None),
#  ('Viet Nam', 2020, None, None, None),
#  ('Wallis and Futuna Islands', 2015, None, None, None),
#  ('Wallis and Futuna Islands', 2016, None, None, None),
#  ('Wallis and Futuna Islands', 2017, None, None, None),
#  ('Wallis and Futuna Islands', 2018, None, None, None),
#  ('Wallis and Futuna Islands', 2019, None, None, None),
#  ('Wallis and Futuna Islands', 2020, None, None, None),
#  ('Yemen', 2015, None, None, None),
#  ('Yemen', 2016, None, None, None),
#  ('Yemen', 2017, None, None, None),
#  ('Yemen', 2018, None, None, None),
#  ('Yemen', 2019, None, None, None),
#  ('Yemen', 2020, None, None, None),
#  ('Zambia', 2015, Decimal('21.25'), Decimal('16.248230'), None),
#  ('Zambia', 2016, Decimal('20.96'), Decimal('16.767761'), None),
#  ('Zimbabwe', 2015, Decimal('19.96'), Decimal('14.154937'), None),
#  ('Zimbabwe', 2016, Decimal('20.55'), Decimal('14.452704'), None),
#  ('Zimbabwe', 2017, Decimal('17.58'), Decimal('14.751101'), None),
#  ('Zimbabwe', 2018, Decimal('34.16'), Decimal('15.052184'), None),
#  ('Zimbabwe', 2020, Decimal('21.51'), Decimal('15.669666'), None),
#  ('Qatar', 2019, Decimal('175.84'), Decimal('2.807235'), Decimal('0.10')),
#  ('Qatar', 2018, Decimal('183.33'), Decimal('2.766732'), Decimal('0.11')),
#  ('Cambodia', 2017, Decimal('22.18'), Decimal('15.830689'), Decimal('0.14')),
#  ('Qatar', 2017, Decimal('161.10'), Decimal('2.711755'), Decimal('0.14')),
#  ('Qatar', 2020, Decimal('144.41'), Decimal('2.760385'), Decimal('0.14')),
#  ('Qatar', 2016, Decimal('151.73'), Decimal('2.595166'), Decimal('0.15')),
#  ('Qatar', 2015, Decimal('161.74'), Decimal('2.414573'), Decimal('0.17')),
#  ('Cambodia', 2015, Decimal('18.05'), Decimal('15.417523'), Decimal('0.39')),
#  ('Myanmar', 2019, Decimal('68.70'), Decimal('53.040212'), Decimal('0.41')),
#  ('Cambodia', 2019, Decimal('27.09'), Decimal('16.207746'), Decimal('0.50')),
#  ('Thailand', 2015, Decimal('401.30'), Decimal('70.294397'), Decimal('0.60')),
#  ('Thailand', 2016, Decimal('413.37'), Decimal('70.607037'), Decimal('0.69')),
#  ('Cambodia', 2016, Decimal('20.02'), Decimal('15.624584'), Decimal('0.72')),
#  ('Thailand', 2019, Decimal('544.08'), Decimal('71.307763'), Decimal('0.72')),
#  ('Myanmar', 2015, Decimal('63.05'), Decimal('51.483949'), Decimal('0.77')),
#  ('Myanmar', 2018, Decimal('67.14'), Decimal('52.666014'), Decimal('0.77')),
#  ('Palau', 2020, Decimal('0.25'), Decimal('0.017972'), Decimal('0.77')),
#  ('Thailand', 2018, Decimal('506.75'), Decimal('71.127802'), Decimal('0.77')),
#  ('Thailand', 2017, Decimal('456.36'), Decimal('70.898202'), Decimal('0.83')),
#  ('Malawi', 2020, Decimal('12.18'), Decimal('19.377061'), Decimal('0.91')),
#  ('Burundi', 2020, Decimal('2.65'), Decimal('12.220227'), Decimal('1.03')),
#  ('Thailand', 2020, Decimal('499.68'), Decimal('71.475664'), Decimal('1.10')),
#  ('Chad', 2018, Decimal('11.24'), Decimal('15.604210'), Decimal('1.13')),
#  ('Myanmar', 2017, Decimal('61.45'), Decimal('52.288341'), Decimal('1.36')),
#  ('Mali', 2016, Decimal('14.03'), Decimal('18.700106'), Decimal('1.37')),
#  ('Benin', 2018, Decimal('14.26'), Decimal('11.940683'), Decimal('1.47')),
#  ('Myanmar', 2020, Decimal('78.93'), Decimal('53.423198'), Decimal('1.48')),
#  ('Mali', 2018, Decimal('17.07'), Decimal('19.934298'), Decimal('1.62')),
#  ('United Arab Emirates', 2016, Decimal('369.26'), Decimal('8.994263'), Decimal('1.64')),
#  ('Cuba', 2017, Decimal('96.85'), Decimal('11.336405'), Decimal('1.70')),
#  ('Cuba', 2018, Decimal('100.05'), Decimal('11.328244'), Decimal('1.70')),
#  ('Madagascar', 2015, Decimal('11.32'), Decimal('24.850912'), Decimal('1.79')),
#  ('Oman', 2018, Decimal('91.51'), Decimal('4.601157'), Decimal('1.80')),
#  ('Cuba', 2016, Decimal('91.37'), Decimal('11.342012'), Decimal('2.00')),
#  ('Kuwait', 2016, Decimal('109.42'), Decimal('4.048085'), Decimal('2.16')),
#  ('Guatemala', 2019, Decimal('77.17'), Decimal('16.604026'), Decimal('2.19')),
#  ('Kuwait', 2015, Decimal('114.57'), Decimal('3.908743'), Decimal('2.20')),
#  ('Togo', 2015, Decimal('4.18'), Decimal('7.473229'), Decimal('2.20')),
#  ('Philippines', 2019, Decimal('376.82'), Decimal('110.380804'), Decimal('2.24')),
#  ('United Arab Emirates', 2018, Decimal('427.05'), Decimal('9.140169'), Decimal('2.24')),
#  ('Tonga', 2018, Decimal('0.49'), Decimal('0.105150'), Decimal('2.25')),
#  ('Guatemala', 2018, Decimal('73.33'), Decimal('16.346950'), Decimal('2.28')),
#  ('United Arab Emirates', 2019, Decimal('417.99'), Decimal('9.211657'), Decimal('2.33')),
#  ('Philippines', 2018, Decimal('346.84'), Decimal('108.568836'), Decimal('2.34')),
#  ('Japan', 2019, Decimal('5123.32'), Decimal('126.633000'), Decimal('2.35')),
#  ('Cuba', 2015, Decimal('87.13'), Decimal('11.339894'), Decimal('2.40')),
#  ('Trinidad and Tobago', 2015, Decimal('26.85'), Decimal('1.460177'), Decimal('2.43')),
#  ('Bhutan', 2015, Decimal('2.00'), Decimal('0.743274'), Decimal('2.45')),
#  ('Guatemala', 2017, Decimal('71.65'), Decimal('16.087418'), Decimal('2.46')),
#  ('United Arab Emirates', 2017, Decimal('390.52'), Decimal('9.068296'), Decimal('2.46')),
#  ('Japan', 2018, Decimal('5037.84'), Decimal('126.811000'), Decimal('2.47')),
#  ('Guatemala', 2015, Decimal('62.19'), Decimal('15.567419'), Decimal('2.51')),
#  ('Philippines', 2020, Decimal('361.75'), Decimal('112.190977'), Decimal('2.52')),
#  ('Philippines', 2017, Decimal('328.48'), Decimal('106.738501'), Decimal('2.55')),
#  ('Guatemala', 2016, Decimal('66.05'), Decimal('15.827690'), Decimal('2.58')),
#  ('Philippines', 2016, Decimal('318.63'), Decimal('104.875266'), Decimal('2.70')),
#  ('Bhutan', 2019, Decimal('2.54'), Decimal('0.767459'), Decimal('2.72')),
#  ('Kenya', 2016, Decimal('74.82'), Decimal('47.894670'), Decimal('2.76')),
#  ('Japan', 2020, Decimal('5040.11'), Decimal('126.261000'), Decimal('2.81')),
#  ('Japan', 2017, Decimal('4930.84'), Decimal('126.972000'), Decimal('2.82')),
#  ('Senegal', 2019, Decimal('23.40'), Decimal('16.000781'), Decimal('2.86')),
#  ('Oman', 2020, Decimal('75.91'), Decimal('4.543399'), Decimal('2.94')),
#  ('Seychelles', 2019, Decimal('1.68'), Decimal('0.097625'), Decimal('2.97')),
#  ('Philippines', 2015, Decimal('306.45'), Decimal('103.031365'), Decimal('3.07')),
#  ('Liberia', 2016, Decimal('3.40'), Decimal('4.706097'), Decimal('3.08')),
#  ('Malaysia', 2015, Decimal('301.35'), Decimal('31.068833'), Decimal('3.10')),
#  ('Nepal', 2015, Decimal('24.36'), Decimal('27.610325'), Decimal('3.10')),
#  ('Singapore', 2019, Decimal('375.47'), Decimal('5.703569'), Decimal('3.10')),
#  ('Japan', 2016, Decimal('5003.68'), Decimal('127.076000'), Decimal('3.13')),
#  ('Sierra Leone', 2018, Decimal('4.09'), Decimal('7.861281'), Decimal('3.19')),
#  ('Guinea-Bissau', 2018, Decimal('1.50'), Decimal('1.924955'), Decimal('3.20')),
#  ('Trinidad and Tobago', 2016, Decimal('23.50'), Decimal('1.469330'), Decimal('3.21')),
#  ('Malaysia', 2019, Decimal('365.18'), Decimal('32.804020'), Decimal('3.26')),
#  ('Mexico', 2018, Decimal('1222.41'), Decimal('124.013861'), Decimal('3.27')),
#  ('Oman', 2016, Decimal('75.13'), Decimal('4.398070'), Decimal('3.27')),
#  ('Peru', 2015, Decimal('189.81'), Decimal('30.711863'), Decimal('3.27')),
#  ('Malaysia', 2018, Decimal('358.79'), Decimal('32.399271'), Decimal('3.30')),
#  ('Nicaragua', 2017, Decimal('13.79'), Decimal('6.480532'), Decimal('3.30')),
#  ('Bhutan', 2018, Decimal('2.45'), Decimal('0.762096'), Decimal('3.35')),
#  ('Ghana', 2017, Decimal('60.41'), Decimal('30.222262'), Decimal('3.37')),
#  ('Peru', 2019, Decimal('228.32'), Decimal('32.824861'), Decimal('3.38')),
#  ('Japan', 2015, Decimal('4444.93'), Decimal('127.141000'), Decimal('3.39')),
#  ('Malaysia', 2017, Decimal('319.11'), Decimal('31.975806'), Decimal('3.41')),
#  ('Mexico', 2017, Decimal('1158.91'), Decimal('122.839258'), Decimal('3.42')),
#  ('Mozambique', 2015, Decimal('15.95'), Decimal('26.843246'), Decimal('3.43')),
#  ('Malaysia', 2016, Decimal('301.26'), Decimal('31.526418'), Decimal('3.44')),
#  ('Mexico', 2019, Decimal('1269.01'), Decimal('125.085311'), Decimal('3.48')),
#  ('Peru', 2018, Decimal('222.60'), Decimal('32.203944'), Decimal('3.49')),
#  ('Trinidad and Tobago', 2019, Decimal('23.85'), Decimal('1.519955'), Decimal('3.52')),
#  ('Ecuador', 2018, Decimal('107.56'), Decimal('17.015672'), Decimal('3.53')),
#  ('Mali', 2020, Decimal('17.47'), Decimal('21.224040'), Decimal('3.53')),
#  ('Seychelles', 2018, Decimal('1.64'), Decimal('0.096762'), Decimal('3.53')),
#  ('Malawi', 2017, Decimal('8.94'), Decimal('17.881167'), Decimal('3.54')),
#  ('Pakistan', 2015, Decimal('270.56'), Decimal('210.969298'), Decimal('3.57')),
#  ('Senegal', 2018, Decimal('23.12'), Decimal('15.574909'), Decimal('3.57')),
#  ('Indonesia', 2019, Decimal('1119.10'), Decimal('269.582878'), Decimal('3.59')),
#  ('Ecuador', 2015, Decimal('99.29'), Decimal('16.195902'), Decimal('3.62')),
#  ('Uganda', 2017, Decimal('30.74'), Decimal('40.127085'), Decimal('3.64')),
#  ('Peru', 2017, Decimal('211.01'), Decimal('31.605486'), Decimal('3.69')),
#  ('Seychelles', 2017, Decimal('1.57'), Decimal('0.095843'), Decimal('3.71')),
#  ('Israel', 2019, Decimal('402.47'), Decimal('9.054000'), Decimal('3.73')),
#  ('Peru', 2016, Decimal('191.90'), Decimal('31.132779'), Decimal('3.74')),
#  ('Togo', 2017, Decimal('6.40'), Decimal('7.852795'), Decimal('3.74')),
#  ('Indonesia', 2017, Decimal('1015.62'), Decimal('264.498852'), Decimal('3.78')),
#  ('Singapore', 2015, Decimal('308.00'), Decimal('5.535002'), Decimal('3.79')),
#  ('Ecuador', 2019, Decimal('108.11'), Decimal('17.343740'), Decimal('3.81')),
#  ('Ecuador', 2017, Decimal('104.30'), Decimal('16.696944'), Decimal('3.84')),
#  ('Mexico', 2016, Decimal('1078.49'), Decimal('121.519221'), Decimal('3.85')),
#  ('China', 2017, Decimal('12310.41'), Decimal('1396.215000'), Decimal('3.90')),
#  ('Nicaragua', 2016, Decimal('13.29'), Decimal('6.389235'), Decimal('3.90')),
#  ('Israel', 2018, Decimal('376.69'), Decimal('8.882800'), Decimal('3.92')),
#  ('Seychelles', 2016, Decimal('1.49'), Decimal('0.094677'), Decimal('3.96')),
#  ('El Salvador', 2015, Decimal('23.44'), Decimal('6.231066'), Decimal('4.00')),
#  ('El Salvador', 2018, Decimal('26.02'), Decimal('6.276342'), Decimal('4.01')),
#  ('Sri Lanka', 2017, Decimal('94.38'), Decimal('21.444000'), Decimal('4.05')),
#  ('Vanuatu', 2020, Decimal('0.90'), Decimal('0.311685'), Decimal('4.05')),
#  ('Pakistan', 2018, Decimal('356.13'), Decimal('219.731479'), Decimal('4.08')),
# ...
#  ('Sri Lanka', 2019, Decimal('89.01'), Decimal('21.803000'), Decimal('4.67')),
#  ('Burkina Faso', 2018, Decimal('15.89'), Decimal('20.392723'), Decimal('4.69')),
#  ('Nicaragua', 2015, Decimal('12.76'), Decimal('6.298598'), Decimal('4.70')),
#  ('Israel', 2016, Decimal('322.10'), Decimal('8.546000'), Decimal('4.72')),
#  ('New Zealand', 2017, Decimal('206.62'), Decimal('4.813600'), Decimal('4.74')),
#  ('Kazakhstan', 2019, Decimal('181.67'), Decimal('18.513673'), Decimal('4.80')),
#  ('Pakistan', 2019, Decimal('320.91'), Decimal('223.293280'), Decimal('4.83')),
#  ('Panama', 2016, Decimal('57.91'), Decimal('4.026336'), Decimal('4.84')),
#  ('Azerbaijan', 2019, Decimal('48.17'), Decimal('10.024283'), Decimal('4.85')),
#  ('Kazakhstan', 2018, Decimal('179.34'), Decimal('18.276452'), Decimal('4.85')),
#  ('Mongolia', 2015, Decimal('11.62'), Decimal('2.964749'), Decimal('4.86')),
#  ('Kazakhstan', 2020, Decimal('171.08'), Decimal('18.755666'), Decimal('4.89')),
#  ('Kazakhstan', 2017, Decimal('166.81'), Decimal('18.037776'), Decimal('4.90')),
#  ('China', 2018, Decimal('13894.82'), Decimal('1402.760000'), Decimal('4.93')),
#  ('Kazakhstan', 2015, Decimal('184.39'), Decimal('17.542806'), Decimal('4.93')),
#  ('Azerbaijan', 2018, Decimal('47.11'), Decimal('9.939771'), Decimal('4.94')),
#  ('Azerbaijan', 2015, Decimal('53.07'), Decimal('9.649341'), Decimal('4.96')),
#  ('Azerbaijan', 2017, Decimal('40.87'), Decimal('9.854033'), Decimal('4.96')),
#  ('Kazakhstan', 2016, Decimal('137.28'), Decimal('17.794055'), Decimal('4.96')),
#  ('Jamaica', 2019, Decimal('15.83'), Decimal('2.813773'), Decimal('4.99')),
#  ('Azerbaijan', 2016, Decimal('37.87'), Decimal('9.757812'), Decimal('5.00')),
#  ('El Salvador', 2020, Decimal('24.56'), Decimal('6.292731'), Decimal('5.01')),
#  ('Kenya', 2019, Decimal('100.38'), Decimal('50.951450'), Decimal('5.01')),
#  ('Guinea', 2019, Decimal('13.44'), Decimal('12.877539'), Decimal('5.02')),
#  ('Bhutan', 2020, Decimal('2.33'), Decimal('0.772506'), Decimal('5.03')),
#  ('Zambia', 2018, Decimal('26.31'), Decimal('17.835893'), Decimal('5.03')),
#  ('China', 2019, Decimal('14279.94'), Decimal('1407.745000'), Decimal('5.15')),
#  ('New Zealand', 2016, Decimal('188.84'), Decimal('4.714100'), Decimal('5.15')),
#  ('Uzbekistan', 2015, Decimal('86.20'), Decimal('31.298900'), Decimal('5.15')),
#  ('Australia', 2019, Decimal('1392.23'), Decimal('25.340217'), Decimal('5.16')),
#  ('Uzbekistan', 2016, Decimal('86.14'), Decimal('31.847900'), Decimal('5.16')),
#  ('Israel', 2015, Decimal('303.41'), Decimal('8.380100'), Decimal('5.18')),
#  ('Nicaragua', 2018, Decimal('13.03'), Decimal('6.572233'), Decimal('5.20')),
#  ('Paraguay', 2016, Decimal('36.09'), Decimal('6.266615'), Decimal('5.25')),
#  ('Uzbekistan', 2020, Decimal('59.89'), Decimal('34.232050'), Decimal('5.29')),
#  ('Australia', 2018, Decimal('1428.29'), Decimal('24.966643'), Decimal('5.30')),
#  ('Panama', 2018, Decimal('64.93'), Decimal('4.165255'), Decimal('5.31')),
#  ('Sri Lanka', 2020, Decimal('85.35'), Decimal('21.919000'), Decimal('5.36')),
#  ('Mongolia', 2018, Decimal('13.18'), Decimal('3.163991'), Decimal('5.38')),
#  ('Guam', 2016, Decimal('5.90'), Decimal('0.168346'), Decimal('5.40')),
#  ('New Zealand', 2015, Decimal('178.06'), Decimal('4.609400'), Decimal('5.42')),
#  ('Vanuatu', 2019, Decimal('0.94'), Decimal('0.304404'), Decimal('5.44')),
#  ('Panama', 2017, Decimal('62.20'), Decimal('4.096063'), Decimal('5.46')),
#  ('Jamaica', 2018, Decimal('15.73'), Decimal('2.811835'), Decimal('5.47')),
#  ('Honduras', 2017, Decimal('23.14'), Decimal('9.626842'), Decimal('5.53')),
#  ('Zambia', 2019, Decimal('23.31'), Decimal('18.380477'), Decimal('5.54')),
#  ('Honduras', 2019, Decimal('25.09'), Decimal('9.958829'), Decimal('5.55')),
#  ('Australia', 2017, Decimal('1326.52'), Decimal('24.594202'), Decimal('5.59')),
#  ('Saudi Arabia', 2015, Decimal('654.27'), Decimal('32.749848'), Decimal('5.60')),
#  ('Saudi Arabia', 2016, Decimal('644.94'), Decimal('33.416270'), Decimal('5.60')),
#  ('China', 2020, Decimal('14687.67'), Decimal('1411.100000'), Decimal('5.61')),
#  ('Honduras', 2018, Decimal('24.07'), Decimal('9.792850'), Decimal('5.62')),
#  ('Saudi Arabia', 2019, Decimal('803.62'), Decimal('35.827362'), Decimal('5.64')),
#  ('Canada', 2019, Decimal('1742.02'), Decimal('37.601230'), Decimal('5.66')),
#  ('Australia', 2016, Decimal('1206.54'), Decimal('24.190907'), Decimal('5.71')),
#  ('Maldives', 2016, Decimal('4.38'), Decimal('0.454252'), Decimal('5.77')),
#  ('Canada', 2018, Decimal('1725.33'), Decimal('37.065084'), Decimal('5.83')),
#  ('Dominican Republic', 2017, Decimal('80.00'), Decimal('10.647244'), Decimal('5.83')),
#  ('Uzbekistan', 2017, Decimal('62.08'), Decimal('32.388600'), Decimal('5.83')),
#  ('Dominican Republic', 2018, Decimal('85.56'), Decimal('10.765531'), Decimal('5.86')),
#  ('Saudi Arabia', 2017, Decimal('688.59'), Decimal('34.193122'), Decimal('5.89')),
#  ('Liberia', 2017, Decimal('3.39'), Decimal('4.796631'), Decimal('5.95')),
#  ('Saudi Arabia', 2018, Decimal('816.58'), Decimal('35.018133'), Decimal('6.03')),
#  ('Zambia', 2020, Decimal('18.11'), Decimal('18.927715'), Decimal('6.03')),
#  ('Australia', 2015, Decimal('1350.62'), Decimal('23.815995'), Decimal('6.06')),
#  ('Ecuador', 2020, Decimal('99.29'), Decimal('17.588595'), Decimal('6.11')),
#  ('Dominican Republic', 2020, Decimal('78.84'), Decimal('10.999664'), Decimal('6.13')),
#  ('Honduras', 2015, Decimal('20.98'), Decimal('9.294505'), Decimal('6.15')),
#  ('Dominican Republic', 2019, Decimal('88.94'), Decimal('10.881882'), Decimal('6.18')),
#  ('Paraguay', 2018, Decimal('40.23'), Decimal('6.443328'), Decimal('6.22')),
#  ('Mauritius', 2019, Decimal('14.44'), Decimal('1.265711'), Decimal('6.33')),
#  ('Canada', 2017, Decimal('1649.27'), Decimal('36.545236'), Decimal('6.34')),
#  ('Marshall Islands', 2019, Decimal('0.23'), Decimal('0.044728'), Decimal('6.34')),
#  ('Mongolia', 2017, Decimal('11.48'), Decimal('3.096030'), Decimal('6.36')),
#  ('Panama', 2019, Decimal('66.98'), Decimal('4.232532'), Decimal('6.41')),
#  ('Mauritius', 2018, Decimal('14.74'), Decimal('1.265303'), Decimal('6.43')),
#  ('Australia', 2020, Decimal('1326.90'), Decimal('25.655289'), Decimal('6.46')),
#  ('Chile', 2015, Decimal('242.50'), Decimal('17.870124'), Decimal('6.49')),
#  ('Jamaica', 2020, Decimal('13.81'), Decimal('2.820436'), Decimal('6.50')),
#  ('India', 2019, Decimal('2831.55'), Decimal('1383.112050'), Decimal('6.51')),
#  ('Mongolia', 2020, Decimal('13.31'), Decimal('3.294335'), Decimal('6.59')),
#  ('Paraguay', 2019, Decimal('37.93'), Decimal('6.530026'), Decimal('6.59')),
#  ('Belize', 2017, Decimal('2.29'), Decimal('0.374693'), Decimal('6.60')),
#  ('Brunei Darussalam', 2019, Decimal('13.47'), Decimal('0.438048'), Decimal('6.60')),
#  ('Chile', 2016, Decimal('249.30'), Decimal('18.083879'), Decimal('6.73')),
#  ('Honduras', 2016, Decimal('21.72'), Decimal('9.460798'), Decimal('6.73')),
#  ('Mauritius', 2017, Decimal('13.71'), Decimal('1.264613'), Decimal('6.75')),
#  ('Senegal', 2015, Decimal('17.77'), Decimal('14.356181'), Decimal('6.76')),
#  ('Ghana', 2015, Decimal('49.41'), Decimal('28.870939'), Decimal('6.81')),
#  ('Mauritius', 2016, Decimal('12.59'), Decimal('1.263473'), Decimal('6.81')),
#  ('Guam', 2015, Decimal('5.80'), Decimal('0.167978'), Decimal('6.90')),
#  ('Tajikistan', 2016, Decimal('6.99'), Decimal('8.725318'), Decimal('6.90')),
#  ('Canada', 2015, Decimal('1556.51'), Decimal('35.702908'), Decimal('6.91')),
#  ('Chile', 2017, Decimal('276.36'), Decimal('18.368577'), Decimal('6.95')),
#  ('Belize', 2016, Decimal('2.26'), Decimal('0.367313'), Decimal('7.00')),
#  ('Canada', 2016, Decimal('1527.99'), Decimal('36.109487'), Decimal('7.00')),
#  ('Nigeria', 2016, Decimal('404.65'), Decimal('188.666931'), Decimal('7.06')),
#  ('Cyprus', 2019, Decimal('25.94'), Decimal('1.228836'), Decimal('7.15')),
#  ('Azerbaijan', 2020, Decimal('42.69'), Decimal('10.093121'), Decimal('7.16')),
#  ('Peru', 2020, Decimal('201.71'), Decimal('33.304756'), Decimal('7.18')),
#  ('Chile', 2018, Decimal('295.40'), Decimal('18.701450'), Decimal('7.21')),
#  ('Suriname', 2015, Decimal('5.13'), Decimal('0.575475'), Decimal('7.22')),
#  ('Mongolia', 2016, Decimal('11.18'), Decimal('3.029555'), Decimal('7.24')),
#  ('Chile', 2019, Decimal('278.58'), Decimal('19.039485'), Decimal('7.27')),
#  ('Dominican Republic', 2016, Decimal('75.70'), Decimal('10.527592'), Decimal('7.28')),
#  ('Zimbabwe', 2019, Decimal('21.83'), Decimal('15.354608'), Decimal('7.37')),
#  ('Jamaica', 2017, Decimal('14.81'), Decimal('2.808376'), Decimal('7.40')),
#  ('Brunei Darussalam', 2020, Decimal('12.01'), Decimal('0.441725'), Decimal('7.41')),
#  ('Mali', 2017, Decimal('15.37'), Decimal('19.311355'), Decimal('7.41')),
#  ('Mauritius', 2015, Decimal('12.01'), Decimal('1.262605'), Decimal('7.41')),
#  ('Uruguay', 2015, Decimal('53.27'), Decimal('3.402818'), Decimal('7.49')),
#  ('Paraguay', 2020, Decimal('35.43'), Decimal('6.618695'), Decimal('7.55')),
#  ('Belize', 2015, Decimal('2.21'), Decimal('0.359871'), Decimal('7.58')),
#  ('Dominican Republic', 2015, Decimal('71.16'), Decimal('10.405832'), Decimal('7.61')),
#  ('India', 2018, Decimal('2702.93'), Decimal('1369.003306'), Decimal('7.65')),
#  ('Saudi Arabia', 2020, Decimal('703.37'), Decimal('35.997107'), Decimal('7.66')),
#  ('Costa Rica', 2017, Decimal('60.52'), Decimal('4.993842'), Decimal('7.73')),
#  ('Mali', 2015, Decimal('13.10'), Decimal('18.112907'), Decimal('7.73')),
#  ('Cyprus', 2020, Decimal('25.01'), Decimal('1.237537'), Decimal('7.76')),
#  ('Niger', 2017, Decimal('11.19'), Decimal('21.737922'), Decimal('7.77')),
#  ('Uruguay', 2016, Decimal('57.24'), Decimal('3.413766'), Decimal('7.84')),
#  ('India', 2020, Decimal('2667.69'), Decimal('1396.387127'), Decimal('7.86')),
#  ('Uruguay', 2017, Decimal('64.23'), Decimal('3.422200'), Decimal('7.89')),
#  ('Suriname', 2016, Decimal('3.32'), Decimal('0.581453'), Decimal('7.92')),
#  ('Costa Rica', 2016, Decimal('58.85'), Decimal('4.945205'), Decimal('8.09')),
#  ('Barbados', 2016, Decimal('4.83'), Decimal('0.278649'), Decimal('8.25')),
#  ('Puerto Rico', 2019, Decimal('105.13'), Decimal('3.193694'), Decimal('8.30')),
#  ('Barbados', 2018, Decimal('5.10'), Decimal('0.279688'), Decimal('8.32')),
#  ('Uruguay', 2018, Decimal('64.52'), Decimal('3.427042'), Decimal('8.34')),
#  ('Argentina', 2017, Decimal('643.63'), Decimal('44.044811'), Decimal('8.35')),
#  ('Nigeria', 2017, Decimal('375.75'), Decimal('193.495907'), Decimal('8.39')),
#  ('Barbados', 2019, Decimal('5.32'), Decimal('0.280180'), Decimal('8.41')),
#  ('Costa Rica', 2015, Decimal('56.44'), Decimal('4.895242'), Decimal('8.42')),
#  ('Tuvalu', 2016, Decimal('0.04'), Decimal('0.010852'), Decimal('8.49')),
#  ('Cyprus', 2018, Decimal('25.60'), Decimal('1.218831'), Decimal('8.50')),
#  ('Zambia', 2017, Decimal('25.87'), Decimal('17.298054'), Decimal('8.52')),
#  ('Brazil', 2015, Decimal('1802.21'), Decimal('205.188205'), Decimal('8.54')),
#  ('Kiribati', 2019, Decimal('0.18'), Decimal('0.124241'), Decimal('8.56')),
#  ('Colombia', 2015, Decimal('293.48'), Decimal('47.119728'), Decimal('8.57')),
#  ('Barbados', 2017, Decimal('4.98'), Decimal('0.279187'), Decimal('8.62')),
#  ('Jamaica', 2016, Decimal('14.08'), Decimal('2.802695'), Decimal('8.63')),
#  ('Mauritius', 2020, Decimal('11.40'), Decimal('1.265740'), Decimal('8.63')),
#  ('Brunei Darussalam', 2018, Decimal('13.57'), Decimal('0.434274'), Decimal('8.70')),
#  ('Uruguay', 2019, Decimal('61.23'), Decimal('3.428409'), Decimal('8.73')),
#  ('Colombia', 2016, Decimal('282.83'), Decimal('47.625955'), Decimal('8.92')),
#  ('Uzbekistan', 2019, Decimal('59.91'), Decimal('33.580350'), Decimal('8.98')),
#  ('Costa Rica', 2018, Decimal('62.42'), Decimal('5.040734'), Decimal('9.01')),
#  ('Belize', 2019, Decimal('2.42'), Decimal('0.389095'), Decimal('9.05')),
#  ('Colombia', 2017, Decimal('311.88'), Decimal('48.351671'), Decimal('9.09')),
#  ('Greenland', 2015, Decimal('2.50'), Decimal('0.056114'), Decimal('9.10')),
#  ('Puerto Rico', 2018, Decimal('100.96'), Decimal('3.193354'), Decimal('9.20')),
#  ('Argentina', 2018, Decimal('524.82'), Decimal('44.494502'), Decimal('9.22')),
#  ('Mongolia', 2019, Decimal('14.21'), Decimal('3.232430'), Decimal('9.27')),
#  ('Morocco', 2016, Decimal('111.57'), Decimal('35.107264'), Decimal('9.30')),
#  ('Brunei Darussalam', 2017, Decimal('12.13'), Decimal('0.430276'), Decimal('9.32')),
#  ('Kiribati', 2015, Decimal('0.17'), Decimal('0.116707'), Decimal('9.33')),
#  ('Uzbekistan', 2018, Decimal('52.63'), Decimal('32.956100'), Decimal('9.35')),
#  ('Colombia', 2018, Decimal('334.20'), Decimal('49.276961'), Decimal('9.36')),
#  ('Samoa', 2017, Decimal('0.88'), Decimal('0.207630'), Decimal('9.40')),
#  ('Canada', 2020, Decimal('1645.42'), Decimal('38.037204'), Decimal('9.46')),
#  ('Morocco', 2015, Decimal('110.41'), Decimal('34.680458'), Decimal('9.46')),
#  ('Barbados', 2015, Decimal('4.72'), Decimal('0.278083'), Decimal('9.80')),
#  ('Argentina', 2019, Decimal('447.75'), Decimal('44.938712'), Decimal('9.84')),
#  ('Algeria', 2016, Decimal('160.03'), Decimal('40.339329'), Decimal('10.20')),
#  ('Colombia', 2019, Decimal('323.11'), Decimal('50.187406'), Decimal('10.28')),
#  ('Uruguay', 2020, Decimal('53.56'), Decimal('3.429086'), Decimal('10.33')),
#  ('Mauritania', 2017, Decimal('6.80'), Decimal('4.160015'), Decimal('10.34')),
#  ('Mauritania', 2019, Decimal('8.07'), Decimal('4.383849'), Decimal('10.42')),
#  ('Nepal', 2017, Decimal('28.97'), Decimal('28.183426'), Decimal('10.66')),
#  ('Honduras', 2020, Decimal('23.83'), Decimal('10.121763'), Decimal('10.68')),
#  ('Nigeria', 2019, Decimal('448.12'), Decimal('203.304492'), Decimal('10.70')),
#  ('Rwanda', 2018, Decimal('9.64'), Decimal('12.531808'), Decimal('10.76')),
#  ('Puerto Rico', 2017, Decimal('103.45'), Decimal('3.325286'), Decimal('10.80')),
#  ('Costa Rica', 2019, Decimal('64.42'), Decimal('5.084532'), Decimal('10.81')),
#  ('Iraq', 2016, Decimal('166.60'), Decimal('38.697943'), Decimal('10.82')),
#  ('New Caledonia', 2019, Decimal('9.44'), Decimal('0.271230'), Decimal('10.88')),
#  ('Chile', 2020, Decimal('252.73'), Decimal('19.300315'), Decimal('10.94')),
#  ('Kiribati', 2020, Decimal('0.18'), Decimal('0.126463'), Decimal('10.97')),
#  ('Cyprus', 2017, Decimal('22.95'), Decimal('1.208523'), Decimal('11.16')),
#  ('Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18')),
#  ('Algeria', 2015, Decimal('165.98'), Decimal('39.543154'), Decimal('11.21')),
#  ('Rwanda', 2019, Decimal('10.36'), Decimal('12.835028'), Decimal('11.24')),
#  ('Cabo Verde', 2019, Decimal('1.98'), Decimal('0.577030'), Decimal('11.29')),
#  ('Lebanon', 2019, Decimal('51.95'), Decimal('5.781907'), Decimal('11.30')),
#  ('Argentina', 2020, Decimal('385.54'), Decimal('45.376763'), Decimal('11.46')),
#  ('Georgia', 2019, Decimal('17.47'), Decimal('3.720161'), Decimal('11.57')),
#  ('Brazil', 2016, Decimal('1795.70'), Decimal('206.859578'), Decimal('11.58')),
#  ('New Caledonia', 2017, Decimal('9.17'), Decimal('0.270810'), Decimal('11.68')),
#  ('New Caledonia', 2018, Decimal('9.85'), Decimal('0.271170'), Decimal('11.70')),
#  ('Afghanistan', 2020, Decimal('20.14'), Decimal('38.972230'), Decimal('11.71')),
#  ('Georgia', 2020, Decimal('15.84'), Decimal('3.722716'), Decimal('11.73')),
#  ('Puerto Rico', 2016, Decimal('104.34'), Decimal('3.406672'), Decimal('11.80')),
#  ('Rwanda', 2020, Decimal('10.18'), Decimal('13.146362'), Decimal('11.83')),
#  ('Rwanda', 2017, Decimal('9.25'), Decimal('12.230339'), Decimal('11.88')),
#  ('Brazil', 2019, Decimal('1873.27'), Decimal('211.782878'), Decimal('11.94')),
#  ('Algeria', 2017, Decimal('170.10'), Decimal('41.136546'), Decimal('12.00')),
#  ('Puerto Rico', 2015, Decimal('103.38'), Decimal('3.473232'), Decimal('12.00')),
#  ('Cabo Verde', 2018, Decimal('1.97'), Decimal('0.571202'), Decimal('12.17')),
#  ('Armenia', 2020, Decimal('12.64'), Decimal('2.805608'), Decimal('12.18')),
#  ('Armenia', 2019, Decimal('13.62'), Decimal('2.820602'), Decimal('12.20')),
#  ('Cabo Verde', 2017, Decimal('1.77'), Decimal('0.564954'), Decimal('12.24')),
#  ('Brazil', 2018, Decimal('1916.95'), Decimal('210.166592'), Decimal('12.33')),
#  ('Georgia', 2018, Decimal('17.60'), Decimal('3.726549'), Decimal('12.67')),
#  ...]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Create a table that contains data about access to basic services for each country and year only.

# %%
# %%sql
#
# CREATE TABLE united_nations.Basic_Services (
#       Country_name VARCHAR(37),
#       Time_period INTEGER,
#       Pct_managed_drinking_water_services NUMERIC(5,2),
#       Pct_managed_sanitation_services NUMERIC(5,2),
#       PRIMARY KEY (Country_name, Time_period),
#       FOREIGN KEY (Country_name) REFERENCES Geographic_Location (Country_name)
# );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.OperationalError) (1050, "Table 'basic_services' already exists")
# [SQL: CREATE TABLE united_nations.Basic_Services (
#       Country_name VARCHAR(37),
#       Time_period INTEGER,
#       Pct_managed_drinking_water_services NUMERIC(5,2),
#       Pct_managed_sanitation_services NUMERIC(5,2),
#       PRIMARY KEY (Country_name, Time_period),
#       FOREIGN KEY (Country_name) REFERENCES Geographic_Location (Country_name)
# );]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# Since our main Access to Basic Services table contains measurements of basic services for each country and year, it implies that every unique country and year will have unique measurements. In other words, both `Country_name` and `Time_period` identify each unique entry. Therefore, `Country_name` and `Time_period` are the composite keys that make up the primary key.
#
# Furthermore, since we have already created a `Geographic_Location` table that contains the geographic location data for each country, this table will include a foreign key that links the `Country_name` column to the `Country_name` primary key in the `Geographic_Location` table.

# %%
# %%sql
#
# INSERT INTO Basic_Services (Country_name, Time_period, Pct_managed_drinking_water_services, Pct_managed_sanitation_services)
# SELECT Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services
# FROM united_nations.Access_to_Basic_Services;

# %% [markdown]
# ### 2. Create a table that contains the economic indicators.

# %%
# %%sql
#
# CREATE TABLE united_nations.Economic_Indicators (
#   Country_name VARCHAR(37),
#   Time_period INTEGER,
#   Est_gdp_in_billions NUMERIC(8,2),
#   Est_population_in_millions NUMERIC(11,6),
#   Pct_unemployment NUMERIC(5,2),
#   PRIMARY KEY (Country_name, Time_period),
#   FOREIGN KEY (Country_name) REFERENCES Geographic_Location (Country_name)
# );

# %% [markdown]
# Again, since we have these metrics per country and per year, `Country_name` and `Time_period` are the composite keys that make up the primary key, and we will have a foreign key that links the `Country_name` column to the `Country_name` primary key in the `Geographic_Location` table.

# %%
INSERT INTO Economic_Indicators (Country_name, Time_period, Est_gdp_in_billions, Est_population_in_millions, Pct_unemployment)
SELECT Country_name,
    Time_period,
    Est_gdp_in_billions,
    Est_population_in_millions,
    Pct_unemployment    
FROM united_nations.Access_to_Basic_Services;

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
