# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Primary keys: Create Geographic_Location table
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we demonstrate how to divide a larger dataset into smaller tables and link them using relationships.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this train, you should:
# - Understand how to extract specific related columns from a table to create a new table that will be linked with the rest of the tables using a relation.
# - Understand how to create a primary key and the uniqueness constraint.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our Access_to_Basic_Services table created in MySQL Workbench, we are interested in creating a table that contains only the geographic location data for each country. We can apply the same queries in MySQL Workbench and in this notebook if we connect to our MySQL server. Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Bruhan123$@localhost:3306/united_nations

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line, and then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Geographic_Location
# LIMIT 20;

# %% [markdown]
# ## Exercise
#
# We want to do the following:
# 1. Create a table named `Geographic_Location`.
# 2. Extract the relevant columns from the `Access_to_Basic_Services` table into the `Geographic_Location` table.

# %% [markdown]
# ### 1. Create a table named Geographic_Location.
#
# Create a table named `Geographic_Location` with the columns `Country_name`, `Sub_region`, `Region`, and `Land_area`, with `Country_name` being the primary key.

# %%
# %%sql
# CREATE TABLE united_nations.Geographic_Location (
#     Country_name VARCHAR(37) PRIMARY KEY,
#     Sub_region VARCHAR(25),
#     Region VARCHAR(32),
#     Land_area NUMERIC(10,2)
# );

# %% [markdown]
# ### 2. Extract the relevant columns from the Access_to_Basic_Services table.
#
# Extract the columns `Country_name`, `Sub_region`, `Region`, and `Land_area` from the `Access_to_Basic_Services` table into the newly created `Geographic_Location` table.

# %%
# %%sql
# -- INSERT INTO united_nations.Geographic_Location (Country_name, Sub_region, Region, Land_area), Already exists
# SELECT Country_name,
#     Sub_region,
#     Region,
#     AVG(Land_area) as Country_area
# FROM united_nations.Access_to_Basic_Services
# GROUP BY Country_name,
#     Sub_region,
#     Region
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# [('Kazakhstan', 'Central Asia', 'Central and Southern Asia', Decimal('2699700.0000')),
#  ('Kyrgyzstan', 'Central Asia', 'Central and Southern Asia', None),
#  ('Tajikistan', 'Central Asia', 'Central and Southern Asia', Decimal('138790.0000')),
#  ('Turkmenistan', 'Central Asia', 'Central and Southern Asia', Decimal('469930.0000')),
#  ('Uzbekistan', 'Central Asia', 'Central and Southern Asia', Decimal('440595.1667')),
#  ('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.0000')),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.0000')),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.5000')),
#  ('India', 'Southern Asia', 'Central and Southern Asia', Decimal('2973190.0000')),
#  ('Iran (Islamic Republic of)', 'Southern Asia', 'Central and Southern Asia', None),
#  ('Maldives', 'Southern Asia', 'Central and Southern Asia', Decimal('300.0000')),
#  ('Nepal', 'Southern Asia', 'Central and Southern Asia', Decimal('143350.0000')),
#  ('Pakistan', 'Southern Asia', 'Central and Southern Asia', Decimal('770880.0000')),
#  ('Sri Lanka', 'Southern Asia', 'Central and Southern Asia', Decimal('61877.8333')),
#  ('China', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('9424702.0000')),
#  ("Democratic People's Republic of Korea", 'Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Japan', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('364500.0000')),
#  ('Mongolia', 'Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('1557297.5000')),
#  ('Republic of Korea', 'Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Brunei Darussalam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('5270.0000')),
#  ('Cambodia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('176520.0000')),
#  ('Indonesia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('1877519.0000')),
#  ("Lao People's Democratic Republic", 'South-Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Malaysia', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('328550.0000')),
#  ('Myanmar', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('652780.0000')),
#  ('Philippines', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('298170.0000')),
#  ('Singapore', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('713.0000')),
#  ('Thailand', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('510890.0000')),
#  ('Timor-Leste', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', Decimal('14870.0000')),
#  ('Viet Nam', 'South-Eastern Asia', 'Eastern and South-Eastern Asia', None),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.0000')),
#  ('Canada', 'Northern America', 'Europe and Northern America', Decimal('8965590.0000')),
#  ('Greenland', 'Northern America', 'Europe and Northern America', Decimal('410450.0000')),
#  ('Saint Pierre and Miquelon', 'Northern America', 'Europe and Northern America', None),
#  ('United States of America', 'Northern America', 'Europe and Northern America', None),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.0000')),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.0000')),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.0000')),
#  ('British Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('150.0000')),
#  ('Cayman Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('240.0000')),
#  ('Cuba', 'Caribbean', 'Latin America and the Caribbean', Decimal('103890.0000')),
#  ('CuraÃ§ao', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Dominica', 'Caribbean', 'Latin America and the Caribbean', Decimal('750.0000')),
#  ('Dominican Republic', 'Caribbean', 'Latin America and the Caribbean', Decimal('48310.0000')),
#  ('Grenada', 'Caribbean', 'Latin America and the Caribbean', Decimal('340.0000')),
#  ('Guadeloupe', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Haiti', 'Caribbean', 'Latin America and the Caribbean', Decimal('27560.0000')),
#  ('Jamaica', 'Caribbean', 'Latin America and the Caribbean', Decimal('10830.0000')),
#  ('Martinique', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Montserrat', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Puerto Rico', 'Caribbean', 'Latin America and the Caribbean', Decimal('8870.0000')),
#  ('Saint BarthÃ©lemy', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Kitts and Nevis', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Lucia', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Martin (French Part)', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Saint Vincent and the Grenadines', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Sint Maarten (Dutch part)', 'Caribbean', 'Latin America and the Caribbean', Decimal('34.0000')),
#  ('Trinidad and Tobago', 'Caribbean', 'Latin America and the Caribbean', Decimal('5130.0000')),
#  ('Turks and Caicos Islands', 'Caribbean', 'Latin America and the Caribbean', Decimal('950.0000')),
#  ('United States Virgin Islands', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.0000')),
#  ('Costa Rica', 'Central America', 'Latin America and the Caribbean', Decimal('51060.0000')),
#  ('El Salvador', 'Central America', 'Latin America and the Caribbean', Decimal('20720.0000')),
#  ('Guatemala', 'Central America', 'Latin America and the Caribbean', Decimal('107160.0000')),
#  ('Honduras', 'Central America', 'Latin America and the Caribbean', Decimal('111890.0000')),
#  ('Mexico', 'Central America', 'Latin America and the Caribbean', Decimal('1943950.0000')),
#  ('Nicaragua', 'Central America', 'Latin America and the Caribbean', Decimal('120340.0000')),
#  ('Panama', 'Central America', 'Latin America and the Caribbean', Decimal('74150.0000')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.0000')),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None),
#  ('Brazil', 'South America', 'Latin America and the Caribbean', Decimal('8358140.0000')),
#  ('Chile', 'South America', 'Latin America and the Caribbean', Decimal('743532.0000')),
#  ('Colombia', 'South America', 'Latin America and the Caribbean', Decimal('1109500.0000')),
#  ('Ecuador', 'South America', 'Latin America and the Caribbean', Decimal('248360.0000')),
#  ('Falkland Islands (Malvinas)', 'South America', 'Latin America and the Caribbean', None),
#  ('French Guiana', 'South America', 'Latin America and the Caribbean', None),
#  ('Guyana', 'South America', 'Latin America and the Caribbean', Decimal('196850.0000')),
#  ('Paraguay', 'South America', 'Latin America and the Caribbean', Decimal('397300.0000')),
#  ('Peru', 'South America', 'Latin America and the Caribbean', Decimal('1280000.0000')),
#  ('Suriname', 'South America', 'Latin America and the Caribbean', Decimal('156000.0000')),
#  ('Uruguay', 'South America', 'Latin America and the Caribbean', Decimal('175020.0000')),
#  ('Venezuela (Bolivarian Republic of)', 'South America', 'Latin America and the Caribbean', None),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.0000')),
#  ('Egypt', 'Northern Africa', 'Northern Africa and Western Asia', None),
#  ('Libya', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('1759540.0000')),
#  ('Morocco', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('446300.0000')),
#  ('Sudan', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('1868000.0000')),
#  ('Tunisia', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('155360.0000')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.0000')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.1667')),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.8333')),
#  ('Cyprus', 'Western Asia', 'Northern Africa and Western Asia', Decimal('9240.0000')),
#  ('Georgia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('69490.0000')),
#  ('Iraq', 'Western Asia', 'Northern Africa and Western Asia', Decimal('434128.0000')),
#  ('Israel', 'Western Asia', 'Northern Africa and Western Asia', Decimal('21640.0000')),
#  ('Jordan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('88784.6667')),
#  ('Kuwait', 'Western Asia', 'Northern Africa and Western Asia', Decimal('17820.0000')),
#  ('Lebanon', 'Western Asia', 'Northern Africa and Western Asia', Decimal('10230.0000')),
#  ('Oman', 'Western Asia', 'Northern Africa and Western Asia', Decimal('309500.0000')),
#  ('Qatar', 'Western Asia', 'Northern Africa and Western Asia', Decimal('11490.0000')),
#  ('Saudi Arabia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('2149690.0000')),
#  ('State of Palestine', 'Western Asia', 'Northern Africa and Western Asia', None),
#  ('Syrian Arab Republic', 'Western Asia', 'Northern Africa and Western Asia', Decimal('183630.0000')),
#  ('TÃ¼rkiye', 'Western Asia', 'Northern Africa and Western Asia', None),
#  ('United Arab Emirates', 'Western Asia', 'Northern Africa and Western Asia', Decimal('71020.0000')),
#  ('Yemen', 'Western Asia', 'Northern Africa and Western Asia', None),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.0000')),
#  ('New Zealand', 'Australia and New Zealand', 'Oceania', Decimal('263310.0000')),
#  ('Fiji', 'Melanesia', 'Oceania', Decimal('18270.0000')),
#  ('New Caledonia', 'Melanesia', 'Oceania', Decimal('18280.0000')),
#  ('Papua New Guinea', 'Melanesia', 'Oceania', Decimal('452860.0000')),
#  ('Solomon Islands', 'Melanesia', 'Oceania', Decimal('27990.0000')),
#  ('Vanuatu', 'Melanesia', 'Oceania', Decimal('12190.0000')),
#  ('Guam', 'Micronesia', 'Oceania', Decimal('540.0000')),
#  ('Kiribati', 'Micronesia', 'Oceania', Decimal('810.0000')),
#  ('Marshall Islands', 'Micronesia', 'Oceania', Decimal('180.0000')),
#  ('Micronesia (Federated States of)', 'Micronesia', 'Oceania', None),
#  ('Nauru', 'Micronesia', 'Oceania', Decimal('20.0000')),
#  ('Northern Mariana Islands', 'Micronesia', 'Oceania', Decimal('460.0000')),
#  ('Palau', 'Micronesia', 'Oceania', Decimal('460.0000')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.0000')),
#  ('Cook Islands', 'Polynesia', 'Oceania', None),
#  ('French Polynesia', 'Polynesia', 'Oceania', Decimal('3471.0000')),
#  ('Niue', 'Polynesia', 'Oceania', None),
#  ('Samoa', 'Polynesia', 'Oceania', Decimal('2796.6667')),
#  ('Tokelau', 'Polynesia', 'Oceania', None),
#  ('Tonga', 'Polynesia', 'Oceania', Decimal('720.0000')),
#  ('Tuvalu', 'Polynesia', 'Oceania', Decimal('30.0000')),
#  ('Wallis and Futuna Islands', 'Polynesia', 'Oceania', None),
#  ('Burundi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('25680.0000')),
#  ('Comoros', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1861.0000')),
#  ('Djibouti', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('23180.0000')),
#  ('Eritrea', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('121083.0000')),
#  ('Ethiopia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('1128559.0000')),
#  ('Kenya', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('569140.0000')),
#  ('Madagascar', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('581800.0000')),
#  ('Malawi', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('94280.0000')),
#  ('Mauritius', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('2030.0000')),
#  ('Mayotte', 'Eastern Africa', 'Sub-Saharan Africa', None),
#  ('Mozambique', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('786380.0000')),
#  ('Rwanda', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('24670.0000')),
#  ('RÃ©union', 'Eastern Africa', 'Sub-Saharan Africa', None),
#  ('Seychelles', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('460.0000')),
#  ('Somalia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('627340.0000')),
#  ('South Sudan', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('631930.0000')),
#  ('Uganda', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('200520.0000')),
#  ('United Republic of Tanzania', 'Eastern Africa', 'Sub-Saharan Africa', None),
#  ('Zambia', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('743390.0000')),
#  ('Zimbabwe', 'Eastern Africa', 'Sub-Saharan Africa', Decimal('386850.0000')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.0000')),
#  ('Cameroon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('472710.0000')),
#  ('Central African Republic', 'Middle Africa', 'Sub-Saharan Africa', Decimal('622980.0000')),
#  ('Chad', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1259200.0000')),
#  ('Congo', 'Middle Africa', 'Sub-Saharan Africa', None),
#  ('Democratic Republic of the Congo', 'Middle Africa', 'Sub-Saharan Africa', None),
#  ('Equatorial Guinea', 'Middle Africa', 'Sub-Saharan Africa', Decimal('28050.0000')),
#  ('Gabon', 'Middle Africa', 'Sub-Saharan Africa', Decimal('257670.0000')),
#  ('Sao Tome and Principe', 'Middle Africa', 'Sub-Saharan Africa', Decimal('960.0000')),
#  ('Botswana', 'Southern Africa', 'Sub-Saharan Africa', Decimal('566730.0000')),
#  ('Eswatini', 'Southern Africa', 'Sub-Saharan Africa', Decimal('17200.0000')),
#  ('Lesotho', 'Southern Africa', 'Sub-Saharan Africa', Decimal('30360.0000')),
#  ('Namibia', 'Southern Africa', 'Sub-Saharan Africa', Decimal('823290.0000')),
#  ('South Africa', 'Southern Africa', 'Sub-Saharan Africa', Decimal('1213090.0000')),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.0000')),
#  ('Burkina Faso', 'Western Africa', 'Sub-Saharan Africa', Decimal('273600.0000')),
#  ('Cabo Verde', 'Western Africa', 'Sub-Saharan Africa', Decimal('4030.0000')),
#  ("CÃ´te d'Ivoire", 'Western Africa', 'Sub-Saharan Africa', None),
#  ('Gambia', 'Western Africa', 'Sub-Saharan Africa', None),
#  ('Ghana', 'Western Africa', 'Sub-Saharan Africa', Decimal('227538.8333')),
#  ('Guinea', 'Western Africa', 'Sub-Saharan Africa', Decimal('245720.0000')),
#  ('Guinea-Bissau', 'Western Africa', 'Sub-Saharan Africa', Decimal('28120.0000')),
#  ('Liberia', 'Western Africa', 'Sub-Saharan Africa', Decimal('96320.0000')),
#  ('Mali', 'Western Africa', 'Sub-Saharan Africa', Decimal('1220190.0000')),
#  ('Mauritania', 'Western Africa', 'Sub-Saharan Africa', Decimal('1030700.0000')),
#  ('Niger', 'Western Africa', 'Sub-Saharan Africa', Decimal('1266700.0000')),
#  ('Nigeria', 'Western Africa', 'Sub-Saharan Africa', Decimal('910770.0000')),
#  ('Saint Helena', 'Western Africa', 'Sub-Saharan Africa', None),
#  ('Senegal', 'Western Africa', 'Sub-Saharan Africa', Decimal('192530.0000')),
#  ('Sierra Leone', 'Western Africa', 'Sub-Saharan Africa', Decimal('72180.0000')),
#  ('Togo', 'Western Africa', 'Sub-Saharan Africa', Decimal('54390.0000'))]

# %%
# %%sql
#
# SELECT Country_name,
#     Sub_region,
#     Region,
#     AVG(Land_area) as Country_area
#
# FROM
#     Geographic_Location
# GROUP BY Country_name,
#     Sub_region,
#     Region
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 20 rows affected.
# [('Afghanistan', 'Southern Asia', 'Central and Southern Asia', Decimal('652230.000000')),
#  ('Algeria', 'Northern Africa', 'Northern Africa and Western Asia', Decimal('2381741.000000')),
#  ('American Samoa', 'Polynesia', 'Oceania', Decimal('200.000000')),
#  ('Angola', 'Middle Africa', 'Sub-Saharan Africa', Decimal('1246700.000000')),
#  ('Anguilla', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Antigua and Barbuda', 'Caribbean', 'Latin America and the Caribbean', Decimal('440.000000')),
#  ('Argentina', 'South America', 'Latin America and the Caribbean', Decimal('2736690.000000')),
#  ('Armenia', 'Western Asia', 'Northern Africa and Western Asia', Decimal('28470.000000')),
#  ('Aruba', 'Caribbean', 'Latin America and the Caribbean', Decimal('180.000000')),
#  ('Australia', 'Australia and New Zealand', 'Oceania', Decimal('7690400.000000')),
#  ('Azerbaijan', 'Western Asia', 'Northern Africa and Western Asia', Decimal('82658.170000')),
#  ('Bahamas', 'Caribbean', 'Latin America and the Caribbean', None),
#  ('Bahrain', 'Western Asia', 'Northern Africa and Western Asia', Decimal('780.830000')),
#  ('Bangladesh', 'Southern Asia', 'Central and Southern Asia', Decimal('130170.000000')),
#  ('Barbados', 'Caribbean', 'Latin America and the Caribbean', Decimal('430.000000')),
#  ('Belize', 'Central America', 'Latin America and the Caribbean', Decimal('22810.000000')),
#  ('Benin', 'Western Africa', 'Sub-Saharan Africa', Decimal('112760.000000')),
#  ('Bermuda', 'Northern America', 'Europe and Northern America', Decimal('54.000000')),
#  ('Bhutan', 'Southern Asia', 'Central and Southern Asia', Decimal('38137.500000')),
#  ('Bolivia (Plurinational State of)', 'South America', 'Latin America and the Caribbean', None)]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Create a table named Geographic_Location.Assumption is that Geographic_Location table doesn't exist in your DB

# %%
# %%sql
#
# CREATE TABLE united_nations.Geographic_Location (
#   Country_name VARCHAR(37) PRIMARY KEY,
#   Sub_region VARCHAR(25),
#   Region VARCHAR(32),
#   Land_area NUMERIC(10,2)
# );

# %% [markdown]
# Remember to create the primary constraint for the `Country_name` column since it will be the identifier for each unique country.

# %% [markdown]
# ### 2. Extract the relevant columns from the Access_to_Basic_Services table.

# %%
# %%sql
#
# INSERT INTO united_nations.Geographic_Location (Country_name, Sub_region, Region, Land_area)
# SELECT Country_name,
#     Sub_region,
#     Region,
#     AVG(Land_area) as Country_area
# FROM united_nations.Access_to_Basic_Services
# GROUP BY Country_name,
#     Sub_region,
#     Region;

# %% [markdown]
# Remember that we specified that the `Country_name` column serves as the primary key for the `Geographic_location` table.
# `Country_name`, however, is not a unique identifier and contains duplicate countries in the `Access_to_Basic_Services` table since the same country names have been recorded many times for various years. The same applies for `Sub_region` and `Region`.
#
# These duplicates will also be copied when the data of this column are transferred to the new `Geographic_Location` table. In order to obtain the unique entries, we must group the data by `Country_name`, `Sub_region`, and `Region`.
#
# By doing this, any "Duplicate entry for primary key" errors will be avoided.

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
