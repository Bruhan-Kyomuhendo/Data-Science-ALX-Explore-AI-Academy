# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Python-Notebook-Banners/Exercise.png"  style="display: block; margin-left: auto; margin-right: auto;";/>
# </div>

# %% [markdown]
# # Exercise: Classes
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we'll be looking at the core principles of object-oriented programming (OOP), and what it means in the context of creating reusable code.

# %% [markdown]
# > **Nudge**: Before you look at the solutions, try your best to work out the problems yourself. The internet is your friend.

# %% [markdown]
# ## Learning objectives
#
# In this train, you should be able to:
# - Understand how the core principles of classes can be used in practice and what it means for writing reusable code.

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Encapsulation
# Create a Python class called `Ecosystem` that represents an ecosystem. This class should have the following attributes:
#
# * `name` (string): The name of the ecosystem (e.g., "Rainforest", "Savanna").
# * `description` (string): A brief description of the ecosystem.
# * `biodiversity_index` (float): A numerical value representing the biodiversity index of the ecosystem (ranging from 0 to 1, where 1 indicates high biodiversity).
#
# Implement methods to:
#
# * Initialise an Ecosystem object with a name, description, and biodiversity index.
# * Display the details of the ecosystem, including its name, description, and biodiversity index.
# * Update the description of the ecosystem.

# %%
# insert code here
class Ecosystem: 
    def __init__(self, name, description, biodiversity_index):
        self.name  =  name 
        self.description = description
        self.biodiversity_index =  biodiversity_index 

    def describe(self):
        return f"This is a {self.name} ecosystem with {self.description}"
    def biodiversity (self):
        if self.biodiversity_index <= 0.01:
            return f"Biodiversity is extremely low"
        elif self.biodiversity_index >= 3.0:
             return f"Biodiversity is moderately high"
        else:
            return f"Biodiversity is very high. Interesting!"
    
                
 # Creating an instance of Ecosystem       
Ecosystem_types1 = Ecosystem( "forest", "different species of plants", 5 )
Ecosystem_types2 = Ecosystem( "river", "water", 0.2)
    
# Describing the ecosystem
print(Ecosystem_types1.describe())
print(Ecosystem_types2.describe())
# Checking the biodiversity level
print(Ecosystem_types1.biodiversity())
print(Ecosystem_types2.biodiversity())
# Out:
# This is a forest ecosystem with different species of plants
# This is a river ecosystem with water
# Biodiversity is moderately high
# Biodiversity is very high. Interesting!

# %% [markdown]
# ### Inheritance
# Create a subclass of `Ecosystem` called `Forest` which should have the following additional attributes:
#
# * `tree_species` (list of strings): A list of tree species found in the forest (initially empty).
# * `carbon_sequestration_rate` (float): A numerical value representing the rate at which the forest sequesters carbon (measured in tons per year).
#
#
# Implement methods to:
#
# * Initialise a Forest object with a name, description, biodiversity index, and carbon sequestration rate.
# * Add a tree species to the list of tree species.
# * Display the tree species in the forest.

# %%
# insert code here
class Ecosystem: 
    def __init__(self, name, description, biodiversity_index):
        self.name  =  name 
        self.description = description
        self.biodiversity_index =  biodiversity_index 

    def describe(self):
        return f"This is a {self.name} ecosystem with {self.description}"
    def biodiversity (self):
        if self.biodiversity_index <= 0.01:
            return f"Biodiversity is extremely low"
        elif self.biodiversity_index >= 3:
             return f"Biodiversity is moderately high"
        else:
            return f"Biodiversity is very high. Interesting!"
 # Here we declare that the Forest  subclass inherits from the Ecosystem class
class Forest(Ecosystem):
    def __init__(self, tree_species, carbon_sequestration_rate):
        # Initialize the parent class with the attributes specific to Forest ecosystem
        super().__init__("forest", "a variety of tree species", 5)
     
        # Initialize additional attributes specific to Forest
        self.tree_species = tree_species
        self.carbon_sequestration_rate = carbon_sequestration_rate

    def add_tree_species(self, species):
        self.tree_species.append(species)

    def display_tree_species(self):
        return f"This forest has the following tree species: {', '.join(self.tree_species)}"
    def describe_forest(self):
        return f"This forest has a variety of tree species: {self.tree_species} which sequester {self.carbon_sequestration_rate} metric tonnes of carbon"

# Create an instance of Forest
forest = Forest(tree_species=["oak", "bamboo", "mahogany"], carbon_sequestration_rate=50)

# Display the forest's description
print(forest.describe())

# Display the forest's tree species
print(forest.display_tree_species())

# Add a new tree species to the forest
forest.add_tree_species("maple")

# Display the updated forest's tree species
print(forest.display_tree_species())
forest.describe_forest()
# Out:
# This is a forest ecosystem with a variety of tree species
# This forest has the following tree species: oak, bamboo, mahogany
# This forest has the following tree species: oak, bamboo, mahogany, maple
# "This forest has a variety of tree species: ['oak', 'bamboo', 'mahogany', 'maple'] which sequester 50 metric tonnes of carbon"

# %%
class Ecosystem: 
    def __init__(self, name, description, biodiversity_index):
        self.name = name 
        self.description = description
        self.biodiversity_index = biodiversity_index 

    def describe(self):
        return f"This is a {self.name} ecosystem with {self.description}"

    def biodiversity(self):
        if self.biodiversity_index <= 0.01:
            return "Biodiversity is extremely low"
        elif self.biodiversity_index >= 3:
            return "Biodiversity is moderately high"
        else:
            return "Biodiversity is very high. Interesting!"
        

# The Forest subclass inherits from the Ecosystem class
class Forest(Ecosystem):
    def __init__(self, tree_species, carbon_sequestration_rate):
        # Initialize the parent class with fixed values for forest ecosystem
        super().__init__(name="forest", description="a variety of tree species", biodiversity_index=5)
        # Initialize additional attributes specific to Forest
        self.tree_species = tree_species
        self.carbon_sequestration_rate = carbon_sequestration_rate

    def describe_forest(self):
        return f"This forest has a variety of the following tree species: {', '.join(self.tree_species)} which sequester {self.carbon_sequestration_rate} metric tonnes of carbon annually."
    

# usage
forest = Forest(tree_species=["oak", "bamboo", "mahogany"], carbon_sequestration_rate=50)

# Describing the forest using the new method
print(forest.describe_forest())

# Checking the biodiversity level
print(forest.biodiversity())
# Out:
# This forest has a variety of the following tree species: oak, bamboo, mahogany which sequester 50 metric tonnes of carbon annually.
# Biodiversity is moderately high

# %% [markdown]
# Note that `', '.join()` construter joins the elements of that list into a single string.
#
# For example the `, ' in ', '.join(self.tree_species) where
# self.tree_species is expected to be a list of tree species (e.g., ["Pine", "Oak", "Birch"]).
# ', '.join(self.tree_species) joins the elements of that list into a single string, with , as the separator between each species.

# %%
class Ecosystem: 
    def __init__(self, name, description, biodiversity_index):
        self.name = name
        self.description = description
        self.biodiversity_index = biodiversity_index 

    def describe(self):
        return f"This is a {self.name} ecosystem with {self.description}"

    def biodiversity(self):
        if self.biodiversity_index <= 0.01:
            return "Biodiversity is extremely low"
        elif self.biodiversity_index >= 3:
            return "Biodiversity is moderately high"
        else:
            return "Biodiversity is very high. Interesting!"
        

# The Forest subclass inherits from the Ecosystem class
class Forest(Ecosystem):
    def __init__(self, tree_species, carbon_sequestration_rate):
        # Initialize the parent class with the appropriate arguments
        super().__init__(name="forest", description="a variety of tree species", biodiversity_index=5) ## defining the attributes of the parent (or super) class
        # Initialize additional attributes specific to Forest
        self.tree_species = tree_species
        self.carbon_sequestration_rate = carbon_sequestration_rate

    def describe_forest(self):
        return f"This forest has the following tree species: {', '.join(self.tree_species)} and sequesters {self.carbon_sequestration_rate} tons of carbon annually."
    

#create an instance of Forest
forest = Forest(tree_species=["Oak", "Pine", "Birch"], carbon_sequestration_rate=150)

# Describing the forest using both the parent and child class methods
print(forest.describe())  # Inherited from Ecosystem
print(forest.describe_forest())  # Specific to Forest

# Checking the biodiversity level
print(forest.biodiversity())
# Out:
# This is a forest ecosystem with a variety of tree species
# This forest has the following tree species: Oak, Pine, Birch and sequesters 150 tons of carbon annually.
# Biodiversity is moderately high

# %% [markdown]
# ### Polymorphism
# Create a class called `Wildlife` that should have a method `habitat` that returns a string describing the habitat of the wildlife. Create two subclasses: `Mammal` and `Bird`. Each subclass should implement the `habitat()` method to describe the habitat of mammals and birds, respectively.

# %%
# insert code here
class Wildlife:
    def __init__(self, wildlife_name, condition, weight):
        self.condition = condition
        self.wildlife_name = wildlife_name
        self.weight = weight

        

    def habitat(self):
        return f"Some {self.wildlife_name}'s can live in {self.condition} and weigh {self.weight} kg"
class Mammal (Wildlife):
    def __init__(self, name, age):
        super().__init__(wildlife_name= "mammal", condition= "kraal", weight= 100)
        self.age = age
        self.name = name

# simulate a mammal-specific behaviour
    def produce(self):
        print(f"{self.name}s  can produce young ones alive")
    def describe(self):
        return f"some {animal.name}'s live up to {animal.age} years old and can weigh {animal.weight} kg. \nWhat an interesting animal to keep!"

# create instance of mammal
animal = Mammal("cow", 150 )

print(animal.habitat())
print(animal.describe())
print(animal.produce())

class Bird (Wildlife):
    def __init__(self, name, age):
        super().__init__(wildlife_name= "bird", condition= "trees", weight= 2)
        self.age = age
        self.name = name

# simulate a bird-specific behaviour
    def fly(self):
        print("birds can fly")
    def describe(self):
        return f'That {bird.name} is {bird.age} years old and weights {bird.weight} kg'

# create instance of bird
bird = Bird("eagle", 20 )

print(bird.habitat())
print(bird.describe())
print(bird.fly())

# Loop through both animal and bird objects
print("loop implementation")
for wildlife_instance in (animal, bird):
    print(wildlife_instance.habitat())
    if isinstance(wildlife_instance, Mammal):
        wildlife_instance.produce()
    else :
        wildlife_instance.fly()
# Out:
# Some mammal's can live in kraal and weigh 100 kg
# some cow's live up to 150 years old and can weigh 100 kg.
# What an interesting animal to keep!
# cows  can produce young ones alive
# None
# Some bird's can live in trees and weigh 2 kg
# That eagle is 20 years old and weights 2 kg
# birds can fly
# None
# loop implementation
# Some mammal's can live in kraal and weigh 100 kg
# cows  can produce young ones alive
# Some bird's can live in trees and weigh 2 kg
# birds can fly

# %%
class Wildlife:
    def __init__(self, wildlife_name, condition, weight):
        self.wildlife_name = wildlife_name
        self.condition = condition
        self.weight = weight

    def habitat(self):
        return f"Some {self.wildlife_name}s can live in {self.condition} and weigh {self.weight} kg."

class Mammal(Wildlife):
    def __init__(self, name, age):
        super().__init__(wildlife_name="mammal", condition="kraal", weight= 100)
        self.age = age
        self.name = name

    # Simulate a mammal-specific behavior
    def produce(self):
        print(f"{self.name}s can produce young ones alive.")

    def describe(self):
        return f"Some {self.name}s live up to {self.age} years and can weigh {self.weight} kg.\nWhat an interesting animal to keep!"

# Create an instance of Mammal
animal = Mammal("cow", 15)

print(animal.habitat())
print(animal.describe())
animal.produce()

class Bird(Wildlife):
    def __init__(self, name, age):
        super().__init__(wildlife_name="bird", condition="trees", weight= 2)
        self.age = age
        self.name = name

    # Simulate a bird-specific behavior
    def fly(self):
        print("Birds can fly.")

    def describe(self):
        return f"That {self.name} is {self.age} years old and weighs {self.weight} kg."

# Create an instance of Bird
bird = Bird("eagle", 20)
print('\n') # create an empty line
print(bird.habitat())
print(bird.describe())
bird.fly()

print('\n') # create an empty line
# Loop through both animal and bird objects
for wildlife_instance in (animal, bird):
    print(wildlife_instance.habitat())   # Calls the habitat method for each object
    if isinstance(wildlife_instance, Mammal):
        wildlife_instance.produce() # Calls the Mammal-specific method 'produce'
    if isinstance(wildlife_instance, Bird):
        wildlife_instance.fly()   # Calls the Bird-specific method 'fly'
# Out:
# Some mammals can live in kraal and weigh 100 kg.
# Some cows live up to 15 years and can weigh 100 kg.
# What an interesting animal to keep!
# cows can produce young ones alive.
#
#
# Some birds can live in trees and weigh 2 kg.
# That eagle is 20 years old and weighs 2 kg.
# Birds can fly.
#
#
# Some mammals can live in kraal and weigh 100 kg.
# cows can produce young ones alive.
# Some birds can live in trees and weigh 2 kg.
# Birds can fly.

# %%
for wildlife_instance in (animal, bird):
    print(wildlife_instance.habitat())  # Calls the habitat method for each object

    if isinstance(wildlife_instance, Mammal):
        wildlife_instance.produce()  # Calls the Mammal-specific method 'produce'
    
    if isinstance(wildlife_instance, Bird):
        wildlife_instance.fly()  # Calls the Bird-specific method 'fly'
# Out:
# Some mammals can live in kraal and weigh 100 kg.
# cows can produce young ones alive.
# Some birds can live in trees and weigh 2 kg.
# Birds can fly.

# %% [markdown]
# ### Abstraction
# Create an abstract base class called `ConservationEfforts` that should have an abstract method `implement_effort()` to describe how a specific conservation effort is implemented. Create two subclasses: `Reforestation` and `WildlifeProtection`. Each subclass should implement the `implement_effort() `method to describe how reforestation and wildlife protection efforts are implemented.
#
# **Hint:** You can use `from abc import ABC, abstractmethod` to create an abstract base class with an abstract method for abstraction.

# %%
# insert code here

from abc import ABC, abstractmethod

class ConservationEfforts(ABC):
    @abstractmethod
    def implement_effort(self):
        pass

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Encapsulation

# %%
# insert code here
class Ecosystem:
    def __init__(self, name, description, biodiversity_index):
        self.name = name
        self.description = description
        self.biodiversity_index = biodiversity_index

    def display_details(self):
        print(f"Ecosystem Name: {self.name}")
        print(f"Description: {self.description}")
        print(f"Biodiversity Index: {self.biodiversity_index}")

    def update_description(self, new_description):
        self.description = new_description

# Create an Ecosystem object
ecosystem = Ecosystem("Rainforest", "Lush and diverse tropical rainforest", 0.85)

# Display ecosystem details
print("Ecosystem Details:")
ecosystem.display_details()

# Update the ecosystem description
ecosystem.update_description("Diverse and vital tropical rainforest")

# Display updated description
print("\nUpdated Ecosystem Description:")
ecosystem.display_details()
# Out:
# Ecosystem Details:
# Ecosystem Name: Rainforest
# Description: Lush and diverse tropical rainforest
# Biodiversity Index: 0.85
#
# Updated Ecosystem Description:
# Ecosystem Name: Rainforest
# Description: Diverse and vital tropical rainforest
# Biodiversity Index: 0.85

# %% [markdown]
# We defined an `Ecosystem` class with attributes `name`, `description`, and `biodiversity_index` to encapsulate information about an ecosystem.
# * The `__init__` method initialises an Ecosystem object with the provided name, description, and biodiversity index.
# * The `display_details` method displays the details of the ecosystem, including its name, description, and biodiversity index.
# * The `update_description` method allows us to update the description of the ecosystem.

# %% [markdown]
# ### Inheritance

# %%
class Forest(Ecosystem):
    def __init__(self, name, description, biodiversity_index, carbon_sequestration_rate):
        super().__init__(name, description, biodiversity_index)
        self.tree_species = []
        self.carbon_sequestration_rate = carbon_sequestration_rate

    def add_tree_species(self, species):
        self.tree_species.append(species)

    def display_tree_species(self):
        print(f"Tree Species in the Forest: {', '.join(self.tree_species)}")

# Create a Forest object
forest = Forest("Tropical Forest", "Dense tropical forest with diverse wildlife", 0.75, 1000.0)

# Display forest details
print("Forest Details:")
forest.display_details()

# Add tree species to the forest
forest.add_tree_species("Mahogany")
forest.add_tree_species("Teak")
forest.add_tree_species("Oak")

# Display tree species in the forest
print("\nTree Species in the Forest:")
forest.display_tree_species()
# Out:
# Forest Details:
# Ecosystem Name: Tropical Forest
# Description: Dense tropical forest with diverse wildlife
# Biodiversity Index: 0.75
#
# Tree Species in the Forest:
# Tree Species in the Forest: Mahogany, Teak, Oak

# %% [markdown]
# The `Forest` class inherits attributes from the `Ecosystem` class and adds additional attributes: `tree_species` and `carbon_sequestration_rate`.
#
# * The `__init__` method initialises a `Forest` object with the provided name, description, biodiversity index, and carbon sequestration rate.
# * The `add_tree_species` method allows us to add tree species to the list of tree species in the forest.
# * The `display_tree_species` method displays the tree species present in the forest.

# %% [markdown]
# ### Polymorphism

# %%
class Wildlife:
    def habitat(self):
        pass

class Mammal(Wildlife):
    def habitat(self):
        return "Mammals can be found in various habitats, including forests, grasslands, and deserts."

class Bird(Wildlife):
    def habitat(self):
        return "Birds inhabit a wide range of environments, including forests, wetlands, and urban areas."

# Create Mammal and Bird objects
mammal = Mammal()
bird = Bird()

# Describe the habitat of mammals and birds
print("Habitat of Mammals:")
print(mammal.habitat())

print("\nHabitat of Birds:")
print(bird.habitat())
# Out:
# Habitat of Mammals:
# Mammals can be found in various habitats, including forests, grasslands, and deserts.
#
# Habitat of Birds:
# Birds inhabit a wide range of environments, including forests, wetlands, and urban areas.

# %% [markdown]
# The `Wildlife` class defines a method `habitat`, which will be implemented differently in subclasses.
#
# We create two subclasses: `Mammal` and `Bird`.
#
# * The `habitat` method in the `Mammal` class describes the habitat of mammals, which can be found in various environments.
# * The `habitat` method in the `Bird` class describes the habitat of birds, which can inhabit a wide range of environments.

# %% [markdown]
# ### Abstraction

# %%
# abstract base class (ABC) 
from abc import ABC, abstractmethod

class ConservationEfforts(ABC):
    @abstractmethod
    def implement_effort(self):
        pass

class Reforestation(ConservationEfforts):
    def implement_effort(self):
        return "Reforestation involves planting trees in deforested areas to restore ecosystems and combat climate change."

class WildlifeProtection(ConservationEfforts):
    def implement_effort(self):
        return "Wildlife protection efforts focus on conserving endangered species and their habitats."

# Create Reforestation and WildlifeProtection objects
reforestation = Reforestation()
wildlife_protection = WildlifeProtection()

# Describe the implementation of conservation efforts
print("Reforestation Effort:")
print(reforestation.implement_effort())

print("\nWildlife Protection Effort:")
print(wildlife_protection.implement_effort())
# Out:
# Reforestation Effort:
# Reforestation involves planting trees in deforested areas to restore ecosystems and combat climate change.
#
# Wildlife Protection Effort:
# Wildlife protection efforts focus on conserving endangered species and their habitats.

# %% [markdown]
# The `ConservationEfforts` class defines an abstract method `implement_effort` that represents a generic conservation effort. We create two subclasses: `Reforestation` and `WildlifeProtection`.
#
# * The `Reforestation` class provides an implementation of the `implement_effort` method, describing the process of reforestation, which involves planting trees to restore ecosystems and combat climate change.
# * The `WildlifeProtection` class provides an implementation of the `implement_effort` method, describing the focus on conserving endangered species and their habitats in wildlife protection efforts.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
