# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Python-Notebook-Banners/Examples.png"  style="display: block; margin-left: auto; margin-right: auto;";/>
# </div>

# %% [markdown]
# # Examples: Python modules
# © ExploreAI Academy

# %% [markdown]
# This notebook accompanies the walk-through video on Python modules and packages and also contains a few additional examples on how we can use modules.

# %% [markdown]
# ## Learning objectives
# In this train, we will learn how to:
# - Write a module and import all or specific objects from a module.
# - Import modules using an alias name and explore the use of built-in modules.
#
#
# ## Outline
# To do this, we will:
# - Define the importance of modules and packages in programming.
# - Review the syntax and conventions for importing modules.
# - Consider the use of built-in Python modules.

# %% [markdown]
# ## Introduction
# Modular programming is a style of programming that promotes code reusability, allowing us to generate single pieces of code which can be used in multiple parts of a project – thus saving time and resources. The resulting code can be simpler to understand and maintain since components can be considered in isolation. In Python, **modularisation** is implemented using functions, modules, and packages.
#
# A **module** is a file consisting of Python code. A module can define functions, classes, variables, and runnable code. These modules can be imported and referenced from other Python code. A **Python package** (also referred to as a library) is a collection of hierarchically structured directories of Python code consisting of sub-packages and modules.
#
# Modules and packages are two mechanisms that facilitate modular programming.
#
# ## Why modularisation?
#
# * **Reusability**: Eliminates the need to write new code, as functionality defined in a single module can be easily reused.
#
#
# * **Simplicity**: Modules generally tend to focus on a selected area of the problem which is usually small, rather than focusing on the entire problem at hand. Integrating the use of selected modules will result in systematically dealing with each small problem in the code, making development easier and less error-prone.
#
#
# * **Maintainability**: Modules in Python are often designed to be self-supporting. In this sense, one module does not depend entirely upon other modules to work. Therefore, it is unlikely that modifying a single module of a program will affect other parts of the program. This allows a team of many programmers or data scientists to work collaboratively on a large application.

# %% [markdown]
# ## Working with modules
#
# ### Creating modules
# Creating a module is as simple as saving a Python script with functions, classes, variables and running code. The file name is the module name with the suffix `.py` appended.
#
# ### Importing modules
# We can access this module and its elements from a different Python file by using the `import` statement.
# * We can import a single module/package:
#
#     ```python
#     import <module_name>
#     ```
#
# * Import multiple modules using individual import statements:
#
#     ```python
#     import <module_1_name>
#     import <module_2_name>
#     import <module_3_name>
#     ...```
#
#
#
# The same rules apply when dealing with packages. We can import specific modules within a package by using dot notation. For this to work, we have to structure packages and modules in a way that reflects the hierarchy in the package directory.
#
#    ```python
#     import <package_name>.<sub_package_name>.<module_name>.<...>
#    ```
#
# Let's go ahead and create our own module, with the following three types of elements:
#
# *   A variable `s`
# *   A function `say_hi()`
# *   A class `Greet`

# %%
# Contents of the module we are creating 
content = """
s = 'Hello ' 

def say_hi(name):
    print(s + name)

class Greet:

    pass
"""

# Write the above text to a file called my_module.py
# within our current working directory. 
with open('./my_module.py', 'w') as fp:
    fp.write(content)

# %% [markdown]
# This command writes (or saves) our module into our working directory so that we can use it again.

# %%
#Import the module we've just made! 
import my_module

# %% [markdown]
# Even though we've imported our module, note that its contents (the variables and functions we've defined within the module) are not directly accessible to us. As such, attempting to access these elements will result in (namespace) errors being thrown. We can safely see such errors using a `try-except` block:

# %%
try:
    # Try to print the variable s
    print(s)
except NameError:
    # We've caught a NameError exception (error!)
    # We inform the programmer (you) that the variable does not exist
    print("Variable 's' does not exist!")
# Out:
# Variable 's' does not exist!

# %% [markdown]
# Learning from this experience, it is important to know that objects in a module are only accessible when prefixed with via dot notation, as illustrated below.

# %%
# Accessing the variable s in my_module
my_module.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function in my_module
my_module.say_hi('Nelson')
# Out:
# Hello Nelson

# %% [markdown]
# ### Example: Importing modules using an alias
# The `import` statement in Python also allows for the use of aliases when referencing a module. Using the `as` keyword, we can save ourselves from having to type otherwise long package names each time we need to access an object from a given module/package. This usually follows the following syntax:
#
# ```python
# import <module_name> as <new_model_name>
# ```
# or
#
# ```python
# from <package_name> import <module_name> as <new_model_name>
# ```
#
# For example:

# %%
# Alias for my_module
import my_module as md

# %% [markdown]
# We can thus treat the alias as the new name for the module.

# %%
# Accessing the variable s using an alias
md.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function using an alias for my_module
md.say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
# Accessing the empty class, Greet
md.Greet
# Out:
# my_module.Greet

# %% [markdown]
# ### Example: Importing modules directly
# Another way to access specific objects in a module is to use the `from` keyword and import them directly:
#
# ```python
# from <module_name> import <x, y, z>
# ```

# %%
from my_module import s, say_hi, Greet

# %%
s
# Out:
# 'Hello '

# %%
say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# We can see that using the `from xx import yy` structure provides access to the individual elements in the module without having to use dot notation. However, using aliases is the recommended way of importing modules and packages, as this prevents potential confusion when different modules contain functions or classes with the same name.
#
# To select all objects from a module we can use the following command, where the asterisk **( * )** *signifies all* :
#
# ```python
# from <module_name> import*
# ```
# Let's see this in practice one more time:

# %%
from my_module import *

# %% [markdown]
# Now we have access to all our module contents.

# %%
say_hi('Joanne')
# Out:
# Hello Joanne

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# ## Built-in modules
# Python contains a large number of what are known as 'built-in' modules. These modules can be accessed in Python programs by simply importing them using their name preceded by the keyword `import`.
#
# Each built-in module contains resources for certain system-specific functionalities such as operating system management, disk input-output, etc. Python scripts (with the **.py** extension) containing useful utilities are embedded within the standard library.
#
# To **display a list of all available modules**, use the following command:
#
# `help('modules')`

# %%
help('modules') # this might take a while
# Out:
# Please wait a moment while I gather a list of all available modules...
# c:\ProgramData\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,
# c:\ProgramData\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# c:\ProgramData\anaconda3\Lib\pkgutil.py:78: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# No QCoreApplication instance found. Application patches not applied. You have to call load_stylesheet function after instantiation of QApplication to take effect.
# 7f0197f6d050da244d93__mypyc code                math                smart_open
# IPython             codecs              matplotlib          smmap
# OpenSSL             codeop              matplotlib_inline   smtplib
# PIL                 collections         mccabe              snappy
# PyQt5               colorama            mdit_py_plugins     sndhdr
# __future__          colorcet            mdurl               sniffio
# __hello__           colorsys            menuinst            snowballstemmer
# __phello__          comm                mimetypes           socket
# _abc                commctrl            mistune             socketserver
# _aix_support        compileall          mkl                 socks
# _argon2_cffi_bindings concurrent          mkl_fft             sockshandler
# _ast                conda               mmap                sortedcontainers
# _asyncio            conda_build         mmapfile            soupsieve
# _bisect             conda_content_trust mmsystem            sphinx
# _black_version      conda_env           modulefinder        spyder
# _blake2             conda_index         more_itertools      spyder_kernels
# _brotli             conda_libmamba_solver mpmath              sqlalchemy
# _bz2                conda_pack          msgpack             sqlite3
# _cffi_backend       conda_package_handling msilib              sre_compile
# _codecs             conda_package_streaming msvcrt              sre_constants
# _codecs_cn          conda_token         multidict           sre_parse
# _codecs_hk          configparser        multipledispatch    ssl
# _codecs_iso2022     constantly          multiprocessing     sspi
# _codecs_jp          contextlib          my_module           sspicon
# _codecs_kr          contextvars         mypy                stack_data
# _codecs_tw          contourpy           mypy_extensions     stat
# _collections        cookiecutter        mypyc               statistics
# _collections_abc    copy                nacl                statsmodels
# _compat_pickle      copyreg             navigator_updater   streamlit
# _compression        cpuinfo             nbclient            string
# _contextvars        crypt               nbconvert           stringprep
# _csv                cryptography        nbformat            struct
# _ctypes             cssselect           nest_asyncio        subprocess
# _ctypes_test        csv                 netbios             sunau
# _datetime           ctypes              netrc               sympy
# _decimal            curl                networkx            symtable
# _distutils_hack     curses              nltk                sys
# _elementtree        cwp                 nntplib             sysconfig
# _functools          cycler              notebook            tables
# _hashlib            cytoolz             notebook_shim       tabnanny
# _heapq              dask                nt                  tabulate
# _imp                dask_expr           ntpath              tarfile
# _io                 dataclasses         ntsecuritycon       tblib
# _json               datashader          nturl2path          telnetlib
# _locale             datetime            numba               tempfile
# _lsprof             dateutil            numbergen           tenacity
# _lzma               dbi                 numbers             terminado
# _markupbase         dbm                 numexpr             test
# _md5                dde                 numpy               test_pycosat
# _msi                debugpy             numpydoc            text_unidecode
# _multibytecodec     decimal             odbc                textdistance
# _multiprocessing    decorator           opcode              textwrap
# _nsis               defusedxml          openpyxl            this
# _opcode             diff_match_patch    operator            threading
# _operator           difflib             optparse            threadpoolctl
# _osx_support        dill                os                  three_merge
# _overlapped         dis                 overrides           tifffile
# _pickle             distributed         packaging           time
# _plotly_future_     distro              pandas              timeit
# _plotly_utils       docstring_to_markdown pandocfilters       timer
# _py_abc             doctest             panel               tinycss2
# _pydatetime         docutils            param               tkinter
# _pydecimal          dotenv              paramiko            tldextract
# _pyio               email               parsel              tlz
# _pylong             encodings           parso               token
# _pytest             ensurepip           partd               tokenize
# _queue              entrypoints         pathlib             toml
# _random             enum                pathspec            tomli
# _sha1               erfa                patsy               tomlkit
# _sha2               errno               pdb                 tomllib
# _sha3               et_xmlfile          perfmon             toolz
# _signal             executing           pexpect             tornado
# _sitebuiltins       fastjsonschema      pickle              tqdm
# _socket             faulthandler        pickleshare         trace
# _sqlite3            filecmp             pickletools         traceback
# _sre                fileinput           pip                 tracemalloc
# _ssl                filelock            pipes               traitlets
# _stat               flake8              pkce                truststore
# _statistics         flask               pkg_resources       tty
# _string             fnmatch             pkginfo             turtle
# _strptime           fontTools           pkgutil             turtledemo
# _struct             fractions           platform            twisted
# _symtable           frozendict          platformdirs        types
# _system_path        frozenlist          plistlib            typing
# _testbuffer         fsspec              plotly              typing_extensions
# _testcapi           ftplib              pluggy              tzdata
# _testclinic         functools           ply                 uc_micro
# _testconsole        gc                  poplib              ujson
# _testimportmultiple genericpath         posixpath           unicodedata
# _testinternalcapi   gensim              pprint              unicodedata2
# _testmultiphase     getopt              profile             unidecode
# _testsinglephase    getpass             prometheus_client   unittest
# _thread             gettext             prompt_toolkit      urllib
# _threading_local    git                 protego             urllib3
# _tkinter            gitdb               pstats              uu
# _tokenize           glob                psutil              uuid
# _tracemalloc        graphlib            pty                 venv
# _typing             greenlet            ptyprocess          w3lib
# _uuid               gzip                pure_eval           warnings
# _warnings           h11                 py                  watchdog
# _weakref            h5py                py_compile          wave
# _weakrefset         hashlib             pyarrow             wcwidth
# _win32sysloader     heapdict            pyasn1              weakref
# _winapi             heapq               pyasn1_modules      webbrowser
# _winxptheme         hmac                pyclbr              webencodings
# _wmi                holoviews           pycodestyle         websocket
# _xxinterpchannels   html                pycosat             werkzeug
# _xxsubinterpreters  http                pycparser           whatthepatch
# _yaml               httpcore            pyct                wheel
# _zoneinfo           httpx               pycurl              widgetsnbextension
# abc                 hvplot              pydantic            win2kras
# adodbapi            hyperlink           pydantic_core       win32api
# aext_assistant      idlelib             pydeck              win32clipboard
# aext_assistant_server idna                pydispatch          win32com
# aext_core           imagecodecs         pydoc               win32con
# aext_core_server    imageio             pydoc_data          win32console
# aext_panels         imagesize           pydocstyle          win32cred
# aext_panels_server  imaplib             pyexpat             win32crypt
# aext_share_notebook imblearn            pyflakes            win32cryptcon
# aext_share_notebook_server imghdr              pygments            win32ctypes
# aext_shared         importlib           pylab               win32event
# afxres              importlib_metadata  pylint              win32evtlog
# aifc                incremental         pylint_venv         win32evtlogutil
# aiobotocore         inflection          pyls_spyder         win32file
# aiohttp             iniconfig           pylsp               win32gui
# aioitertools        inspect             pylsp_black         win32gui_struct
# aiosignal           intake              pylsp_jsonrpc       win32help
# alabaster           intervaltree        pyodbc              win32inet
# altair              io                  pyparsing           win32inetcon
# anaconda_anon_usage ipaddress           pytest              win32job
# anaconda_catalogs   ipykernel           pythoncom           win32lz
# anaconda_cloud_auth ipykernel_launcher  pythonjsonlogger    win32net
# anaconda_navigator  ipython_genutils    pytoolconfig        win32netcon
# anaconda_project    ipywidgets          pytz                win32pdh
# annotated_types     isapi               pyviz_comms         win32pdhquery
# antigravity         isort               pywin               win32pdhutil
# anyio               isympy              pywin32_bootstrap   win32pipe
# appdirs             itemadapter         pywin32_testutil    win32print
# archspec            itemloaders         pywintypes          win32process
# argon2              itertools           pywt                win32profile
# argparse            itsdangerous        qdarkstyle          win32ras
# array               jedi                qstylizer           win32rcparser
# arrow               jellyfish           qtawesome           win32security
# ast                 jinja2              qtconsole           win32service
# astroid             jmespath            qtpy                win32serviceutil
# astropy             joblib              queue               win32timezone
# astropy_iers_data   json                queuelib            win32trace
# asttokens           json5               quopri              win32traceutil
# async_lru           jsonpatch           random              win32transaction
# asyncio             jsonpointer         rasutil             win32ts
# atexit              jsonschema          re                  win32ui
# atomicwrites        jsonschema_specifications referencing         win32uiole
# attr                jupyter             regcheck            win32verstamp
# attrs               jupyter_client      regex               win32wnet
# audioop             jupyter_console     regutil             win_inet_pton
# automat             jupyter_core        repo_cli            winerror
# autopep8            jupyter_events      reprlib             winioctlcon
# babel               jupyter_lsp         requests            winnt
# base64              jupyter_server      requests_file       winperf
# bcrypt              jupyter_server_terminals requests_toolbelt   winpty
# bdb                 jupyterlab          rfc3339_validator   winreg
# binaryornot         jupyterlab_plotly   rfc3986_validator   winsound
# binascii            jupyterlab_pygments rich                winxpgui
# binstar_client      jupyterlab_server   rlcompleter         winxptheme
# bisect              jupyterlab_widgets  rope                wrapt
# black               jwt                 rpds                wsgiref
# blackd              keyring             rtree               xarray
# bleach              keyword             ruamel_yaml         xdrlib
# blib2to3            kiwisolver          runpy               xlwings
# blinker             lazy_loader         s3fs                xlwingsjs
# bokeh               lazy_object_proxy   sched               xml
# boltons             lckr_jupyterlab_variableinspector scipy               xmlrpc
# botocore            lib2to3             scrapy              xxlimited
# bottleneck          libarchive          seaborn             xxlimited_35
# brotli              libmambapy          secrets             xxsubtype
# bs4                 lief                select              xyzservices
# builtins            linecache           selectors           yaml
# bz2                 linkify_it          semver              yapf
# cProfile            llvmlite            send2trash          yapf_third_party
# cachetools          lmdb                service_identity    yapftests
# calendar            locale              servicemanager      yarl
# certifi             locket              setuptools          zict
# cffi                logging             shelve              zipapp
# cgi                 lxml                shlex               zipfile
# cgitb               lz4                 shutil              zipimport
# chardet             lzma                signal              zipp
# charset_normalizer  mailbox             sipbuild            zlib
# chunk               mailcap             site                zmq
# click               markdown            six                 zoneinfo
# cloudpickle         markdown_it         skimage             zope
# cmath               markupsafe          sklearn             zstandard
# cmd                 marshal             slugify
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %% [markdown]
# Alternatively, the `dir()` function is a built-in function that can be used to **list all the function names (or variable names) in a module**:
#
# `dir(module_name)`

# %%
# Import math module 
import math 

# Use the sqrt function in the math module
x = math.sqrt(81)
print('The square root of 81 is equal to {}'.format(x))

# List all functions in math module 
list_all= dir(math)
print('Functions in the math module: {}'.format(list_all))
# Out:
# The square root of 81 is equal to 9.0
# Functions in the math module: ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %% [markdown]
# ## Summary
#
# In this train, we learned how to create, import, and use modules. We also explored the use of built-in modules in Python and how to determine what functions are present within modules.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
