# %% [markdown]
# ## Explanation of how to find out if  a number is prime or not

# %%
# This video better explains how to ho to do a regu;ar expression of a prime number
https://youtu.be/5vbk0TwkokM?si=s76U74WNx3aO1QVa
