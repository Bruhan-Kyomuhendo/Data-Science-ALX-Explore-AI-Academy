# %% [markdown]
# Parametric models, ensembling, and bootstrapping
# © ExploreAI Academy
#
# Additional resources: The links provided contain additional information from external resources.
#
# - [Estimating Prediction Error and Validation Set Approach [ISLR Series]](https://www.youtube.com/watch?v=ngrOYWgJjb4&ab_channel=DataScienceAnalytics)
#
#     > A lesson on resampling methods: cross-validation and the bootstrap.
#     >Training and test set performance will be compared by looking at bias and variance.
#
# - [K-fold Cross-Validation [ISLR Series]](https://www.youtube.com/watch?v=rSGzUy13F_0&ab_channel=DataScienceAnalytics)
#     Estimating test error by using K-fold cross-validation.
#
# - [Cross-Validation: The Right and Wrong Ways [ISLR Series]](https://www.youtube.com/watch?v=r64tRyHFAJ8&ab_channel=DataScienceAnalytics)
#     Look at the rights and wrongs when using cross-validation.
#
# - [The Bootstrap [ISLR Series]](https://www.youtube.com/watch?v=fBaqG3vpIIg&ab_channel=DataScienceAnalytics)
#     Use the bootstrap to estimate the standard error of a coefficient or a confidence interval for that coefficient.
#
# - [More on the Bootstrap [ISLR Series]](https://www.youtube.com/watch?v=uX5kPAK0lpo&ab_channel=DataScienceAnalytics)
#     Learn about using bootstrap in more complex situations.
