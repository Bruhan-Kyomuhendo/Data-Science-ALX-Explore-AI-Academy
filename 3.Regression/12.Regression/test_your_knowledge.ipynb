# %% [markdown]
# test_your_knowledge

# %% [markdown]
# 1. What is the primary issue addressed by data scaling in machine learning models?
#
#
# - A:    `Balancing the influence of different features.`
# - B:    Reducing computation time.
# - C:    Simplifying complex algorithms.
# - D:    Increasing the number of features.

# %% [markdown]
# 2. Ridge regression is used to:
#
#
# - A:    Reduce the impact of irrelevant features.
# - B:    Completely eliminate certain features.
# - C:    Increase the model's complexity.
# - D:    `Smooth the influence of correlated features.`

# %% [markdown]
# 3. LASSO regression is unique because it:
#
#
# - A:    Focuses on increasing feature correlations.
# - B:    Always increases the accuracy of the model.
# - C:   ` Can set some coefficient values to zero.`
# - D:    Requires less data for training.

# %% [markdown]
# 4. True or false? Overfitting occurs when a model is too generalised, performing poorly on both training and new data.
#
# - A:    `False`
# - B:    True
