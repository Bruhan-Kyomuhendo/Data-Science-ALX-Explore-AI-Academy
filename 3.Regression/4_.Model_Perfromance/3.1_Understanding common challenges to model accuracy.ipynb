# %% [markdown]
# 1. Which of the following are solutions to heteroskedasticity?
#
# i. Weighted least squares,
# ii Instrumental variables,
# iii. Using more complex models,
# iv. Transforming variables,
# v. Regularising the model, and
# vi. Panel data analysis
# - `A:    i and iv`
# - B:    ii and iii
# - C:    iv and vi
# - D:    ii and v

# %% [markdown]
# 2. Using the dartboard analogy, which of the following learners can be used to demonstrate low variance and high bias in a model?
#
# - A:    `Naive learner`
# - B:    Terrible learner
# - C:    Ideal learner
# - D:    Good learner

# %% [markdown]
# 3. Which of the following reasons does not highlight the significance of accuracy in models?
#
# - A:    `Optimising the model to generate results faster.`
# - B:    Instilling confidence in the organisation's capabilities which leads to stronger relationships and increased trust with stakeholders.
# - C:    Identifying emerging trends or opportunities, optimising operations, and delivering improved products or services.
# - D:    Getting a better understanding of the underlying processes, relationships, and patterns in data.
