# %% [markdown]
# Test your knowledge on train test split for  a model

# %% [markdown]
# 1. After training a model and evaluating it on both training and testing sets, you find that the Mean Squared Error (MSE) is significantly lower on the training set than on the testing set. What might this indicate about your model's performance?
#
# - `A:   The model has overfit the training data, showing it performs well on training data but poorly on unseen data`
# - B:    The model is perfectly fitted to the data, indicating excellent generalisation.
# - C:    The model's performance is consistent across both sets.
# - D:    The model has underfit the training data, requiring more complexity to capture the underlying patterns

# %% [markdown]
# 2. True or False: The validation set is used to fine-tune the model's parameters and differs from the test set, which is used for an unbiased evaluation of the final model's performance.
#
# - `A:    True`
# - B:    False

# %% [markdown]
# 3. Which of the following lines of code will perform a 70-30 split of a dataset into training and testing sets and ensure reproducibility of the split using train_test_split from sklearn?
#
# - A:    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# - B:    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)
# - C:    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)
# - `D:    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)`

# %% [markdown]
# 4. How does using a separate test set help deal with overfitting in the context of evaluating the performance of a machine learning model?
#
# - A:    It increases the complexity of the model, making it better at predicting outcomes for new inputs.
# - `B:    It ensures that the model is evaluated on data it hasn't seen during training, providing a more accurate measure of its ability to generalise to new data.`
# - C:    It decreases the need for model validation techniques, such as cross-validation.
# - D:    It allows the model to be trained on a larger portion of the dataset, thereby improving its accuracy on unseen data.
