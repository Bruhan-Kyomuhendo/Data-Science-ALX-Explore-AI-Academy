# %% [markdown]
# Additional resources: Model performance

# %% [markdown]
# This reference document is designed to complement and enhance the material we have covered on model performance. It contains additional resources on model performance metrics as well as splitting datasets.
#
# References:
#
# ---

# %% [markdown]
# 1. A Khan Academy lesson on how to compute R-squared:
# - [R-Squared Explained](https://www.khanacademy.org/math/ap-statistics/bivariate-data-ap/assessing-fit-least-squares-regression/v/r-squared-or-coefficient-of-determination "Click Here")
# 2. Learn how to calculate the mean squared error by using Python code:
# - [Calculating Mean Squared Error in Python](https://www.educative.io/edpresso/calculating-mean-squared-error-in-python "Click Here")
# 3. Learn about assessing model accuracy and understand bias-variance trade-off:
# - [Assessing Model Accuracy and Bias-Variance Trade-off [ISLR Series]](https://youtu.be/VaN1RUDuioQ "Click Here")
# 4. An article that covers the various cross-validation techniques and how to implement them with Python code:
# - [Cross-Validation Techniques](https://www.analyticsvidhya.com/blog/2021/11/top-7-cross-validation-techniques-with-python-code/ "Click Here")
# 5. Articles that explain what validation sets are, their importance in the model-building process, and how they differ from test sets:
# - [Training, Validation, and Test Sets](https://kili-technology.com/training-data/training-validation-and-test-sets-how-to-split-machine-learning-data "Click Here")
# - [Difference Between Test and Validation Datasets](https://machinelearningmastery.com/difference-test-validation-datasets/ "Click Here")
