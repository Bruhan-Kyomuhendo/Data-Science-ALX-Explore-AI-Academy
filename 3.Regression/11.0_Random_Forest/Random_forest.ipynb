# %% [markdown]
# Test your knowledge on RandomForest

# %% [markdown]
# How do random forests improve prediction accuracy over a single decision tree?
#
# - A:    By using a larger dataset for training.
# - B:    By creating a single, highly complex tree that fits the training data perfectly.
# - C:    By focusing on only one feature for splitting at each node.
# - D:   `By combining the predictions from multiple trees.`

# %% [markdown]
# What are the two random processes used in building a Random Forest?
#
# - A:    Random splitting of the dataset and random assignment of class labels.
# - B:    Random node selection and random tree pruning.
# - C:    Random generation of data points and random deletion of features.
# - D:    `Bootstrapping of datasets and random feature selection.`

# %% [markdown]
# How does a Random Forest make predictions for classification problems?
#
# - A:    By averaging the predictions from all trees.
# - B:    `Through majority voting among the predictions from all trees.`
# - C:    By selecting the prediction of the tree with the highest accuracy.
# - D:    Using the prediction from the first tree in the forest.
