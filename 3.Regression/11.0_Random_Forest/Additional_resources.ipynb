# %% [markdown]
# ### Additional resources: Random forests
# © ExploreAI Academy
#
# This reference document is designed to complement and enhance the material we have covered on random forests. It contains additional resources that provide a deep dive into the inner workings of the random forest and its implementation.
#
# ### References:
#
# 1. Learn how to create a machine-learning solution using a random forest model:
#
# - [Fast.AI Lesson 1: Introduction to Random Forests](http://course18.fast.ai/lessonsml1/lesson1.html)
#
# 2. Learn about metrics, loss functions, overfitting, individual trees, and bagging with random forests:
#
# - [Fast.AI Lesson 2: Random Forest Deep Dive](http://course18.fast.ai/lessonsml1/lesson2.html)
#
# 3. A lesson on speeding up your code through profiling, picking a validation set, and model interpretation:
#
# - [Fast.AI Lesson 3: Performance, Validations, and Model Interpretation](http://course18.fast.ai/lessonsml1/lesson3.html)
#
# 4. Follow this lesson to learn about feature importance, dendrogram usage, and interpretation techniques such as partial dependence plots and the tree interpreter:
#
# - [Fast.AI Lesson 4: Feature Importance, Tree Interpreter](https://course18.fast.ai/lessonsml1/lesson4.html)
#
# 5. Learn about waterfall charts, extrapolation, and how to write your own random forest from scratch:
#
# - [Fast.AI Lesson 5: Extrapolation and RF from Scratch](https://course18.fast.ai/lessonsml1/lesson5.html)
#
# 6. Follow this lesson to learn about creating data products using “The Drivetrain Method” and a deeper understanding of extrapolation:
#
# - [Fast.AI Lesson 6: Data Products and Live Coding](https://course18.fast.ai/lessonsml1/lesson6.html)
#
# 7. Become familiar with the cython library for increased speed in your code and gradient descent based methods:
#
# - [Fast.AI Lesson 7: RF from Scratch and Gradient Descent](http://course18.fast.ai/lessonsml1/lesson7.html)
#
# 8. An article that provides an implementation and explanation of the random forest in Python:
#
# - [An In-Depth Look Into Random Forests](https://towardsdatascience.com/an-implementation-and-explanation-of-the-random-forest-in-python-77bf308a9b76)
#
# 9. An article that presents ways to compute feature importance using a random forest:
#
# - [Random Forest Feature Importance](https://mljar.com/blog/feature-importance-in-random-forest/)
