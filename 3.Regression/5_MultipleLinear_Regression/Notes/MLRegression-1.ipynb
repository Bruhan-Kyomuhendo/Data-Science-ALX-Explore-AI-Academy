# %% [markdown]
# Multiple linear regression.

# %%
# Check our current working directory
import os.path
cwd = os.getcwd()
print(f"Current working directory: {cwd}")
# Out:
# Current working directory: c:\Users\bruha\OneDrive - University of Pretoria\DS_Course\Regression\5_MultipleLinear_Regression\Notes

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src = "Regression_equation.png " style= "width: 500px;height: 500px">
# </div>
